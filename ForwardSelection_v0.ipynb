# %% [markdown]
# 이 파일은 다음과 같은 부분으로 나뉩니다. <br>
# - 맨 윗부분 <br>
# - **데이터 전처리** <br>
# - **Forward Selection**
# (-> 정규화, 함수 정의, Ridge 파라미터(alpha) 값 테스트, Forward Selection 진행하기)

# %% [markdown]
# ---

# %% [markdown]
# 코드의 맨 윗부분과 '**데이터 전처리**' 부분은 'train_test_guide_v0.ipynb' 파일을 반영했습니다. <br>
# 해당 파일에서 다음만 수정했습니다: <br>
# - 'n_non_stop_words_rounded' 변수 삭제
# - 결측치 처리 셀 한 칸 위로 이동
# - 정규화 추후에 진행
# - ("# 학습" 적혀 있는 셀 전까지의 셀들 사용)

# %% [markdown]
# ---

# %% [markdown]
# RidgePerf 라는 함수를 정의해서 사용했습니다.
# - train과 validation set을 인수로 받아서
# - sklearn.linear_model의 Ridge 모델을 학습,
# - Adjusted R2(성능 지표)를 리턴합니다.
# - 이때 R2 값을 받아서 Adjusted R2 값을 리턴하는 함수 'adjusted_r2'를 따로 정의하여 사용했습니다.
# - RidgePerf 함수를 이용해서 성능 지표 값을 쉽게 얻을 수 있으므로, forward selection을 하는 과정에서 성능 지표를 비교를 및 feature 선택을 자동화할 수 있었습니다.

# %% [markdown]
# Ridge를 이용해 Backward Selection을 하실 때 <br>
# 코드 통일을 위해서:
# - RidgePerf 함수를 그대로 사용하고 싶으시다면 adjusted_r2 함수도 함께 가져가서 사용하시고,
# - 다른 방식으로 Ridge를 사용하고 싶으시다면 sklearn.linear_model에서 import 하셔서 alpha=1로 두고 사용만 하시면 될 것 같습니다.

# %% [markdown]
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 작업 디렉토리 변경
import os
print(os.getcwd(), end=' -> ')
os.chdir('/content/drive/MyDrive/PatternRecognition/project')
print(os.getcwd())
# Out:
# /content -> /content/drive/MyDrive/PatternRecognition/project

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# CSV 파일 불러오기
df = pd.read_csv('train.csv')
df.head()
# Out:
#       id  n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0  17335             9.0             409.0         0.501326               1.0
# 1  21242            10.0             317.0         0.725086               1.0
# 2   9448            11.0             447.0         0.584091               1.0
# 3  36797            13.0             143.0         0.638298               NaN
# 4  29504            17.0             576.0         0.524412               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.587361       23.0             2.0      11.0         0.0
# 1                  0.830097        6.0             3.0       NaN        21.0
# 2                  0.730104        NaN             1.0       1.0         1.0
# 3                  0.787500        3.0             2.0       NaN         0.0
# 4                  0.714286        8.0             3.0       NaN         0.0
#
#    ...  min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0  ...                -0.1875                   -0.1                0.50
# 1  ...                -0.6000                    NaN                0.00
# 2  ...                -0.5000                   -0.1                0.75
# 3  ...                 0.0000                    0.0                1.00
# 4  ...                -1.0000                   -0.1                0.00
#
#    title_sentiment_polarity  abs_title_subjectivity  \
# 0                     0.500                    0.00
# 1                     0.000                    0.50
# 2                     0.125                    0.25
# 3                       NaN                    0.50
# 4                     0.000                    0.50
#
#    abs_title_sentiment_polarity  data_channel    weekday  shares  y
# 0                         0.500     Lifestyle        NaN     801  0
# 1                         0.000     Lifestyle    Tuesday     426  0
# 2                         0.125         World     Friday    2400  1
# 3                         0.500  Social Media        NaN    1100  0
# 4                         0.000         World  Wednesday    1500  1
#
# [5 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22200 entries, 0 to 22199
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            22200 non-null  int64
#  1   n_tokens_title                20000 non-null  float64
#  2   n_tokens_content              20054 non-null  float64
#  3   n_unique_tokens               19942 non-null  float64
#  4   n_non_stop_words              20017 non-null  float64
#  5   n_non_stop_unique_tokens      19944 non-null  float64
#  6   num_hrefs                     19967 non-null  float64
#  7   num_self_hrefs                19920 non-null  float64
#  8   num_imgs                      19986 non-null  float64
#  9   num_videos                    19906 non-null  float64
#  10  average_token_length          19987 non-null  float64
#  11  num_keywords                  19955 non-null  float64
#  12  kw_min_min                    19984 non-null  float64
#  13  kw_max_min                    20021 non-null  float64
#  14  kw_avg_min                    19971 non-null  float64
#  15  kw_min_max                    19985 non-null  float64
#  16  kw_max_max                    19968 non-null  float64
#  17  kw_avg_max                    20040 non-null  float64
#  18  kw_min_avg                    20049 non-null  float64
#  19  kw_max_avg                    20018 non-null  float64
#  20  kw_avg_avg                    20023 non-null  float64
#  21  self_reference_min_shares     19994 non-null  float64
#  22  self_reference_max_shares     20026 non-null  float64
#  23  self_reference_avg_sharess    19954 non-null  float64
#  24  LDA_00                        19976 non-null  float64
#  25  LDA_01                        19998 non-null  float64
#  26  LDA_02                        20047 non-null  float64
#  27  LDA_03                        19957 non-null  float64
#  28  LDA_04                        20013 non-null  float64
#  29  global_subjectivity           19946 non-null  float64
#  30  global_sentiment_polarity     19969 non-null  float64
#  31  global_rate_positive_words    19966 non-null  float64
#  32  global_rate_negative_words    19951 non-null  float64
#  33  rate_positive_words           19981 non-null  float64
#  34  rate_negative_words           19958 non-null  float64
#  35  avg_positive_polarity         20050 non-null  float64
#  36  min_positive_polarity         19958 non-null  float64
#  37  max_positive_polarity         20033 non-null  float64
#  38  avg_negative_polarity         19916 non-null  float64
#  39  min_negative_polarity         19926 non-null  float64
#  40  max_negative_polarity         19997 non-null  float64
#  41  title_subjectivity            19928 non-null  float64
#  42  title_sentiment_polarity      19967 non-null  float64
#  43  abs_title_subjectivity        19934 non-null  float64
#  44  abs_title_sentiment_polarity  19951 non-null  float64
#  45  data_channel                  20053 non-null  object
#  46  weekday                       20087 non-null  object
#  47  shares                        22200 non-null  int64
#  48  y                             22200 non-null  int64
# dtypes: float64(44), int64(3), object(2)
# memory usage: 8.3+ MB

# %%
# 공유 수 분포 그래프
sns.kdeplot(df['shares'])
plt.xlim(0, 20000)
# Out:
# (0.0, 20000.0)

# %% [markdown]
# # **데이터 전처리**

# %%
# 가장 많이 등장한 값이 전체에서 차지하는 비율 top 10
top_ratio_dict = {}

for col in df.columns:
    most_common = df[col].value_counts(dropna=False).iloc[0]
    total = len(df)
    ratio = most_common / total
    top_ratio_dict[col] = ratio

top_10 = sorted(top_ratio_dict.items(), key=lambda x: x[1], reverse=True)[:10]

for col, ratio in top_10:
    print(f"{col}: {ratio:.2%}")
# Out:
# kw_max_max: 68.41%
# num_videos: 56.30%
# kw_min_min: 51.76%
# y: 50.43%
# abs_title_subjectivity: 46.68%
# title_sentiment_polarity: 45.55%
# abs_title_sentiment_polarity: 45.47%
# num_imgs: 41.08%
# title_subjectivity: 40.79%
# kw_min_avg: 39.03%

# %%
# 중복 값이 많은 변수들을 자세히 살펴보자
df['kw_min_min'].value_counts(dropna=False).head(5)
# Out:
# kw_min_min
# -1.0      11491
#  4.0       6074
#  217.0     2367
#  NaN       2216
#  0.0         34
# Name: count, dtype: int64

# %%
df['kw_max_max'].value_counts(dropna=False).head(5)
# Out:
# kw_max_max
# 843300.0    15186
# NaN          2232
# 690400.0     2017
# 617900.0     1143
# 69100.0       654
# Name: count, dtype: int64

# %%
df['n_non_stop_words_rounded'] = df['n_non_stop_words'].round(3)  # 소수 셋째 자리까지 반올림
df['n_non_stop_words_rounded'].value_counts(dropna=False)
# Out:
# n_non_stop_words_rounded
# 1.0    19420
# NaN     2183
# 0.0      597
# Name: count, dtype: int64

# %%
# 많은 값들이 같은 값을 가지므로 삭제한다
df.drop(columns=['kw_min_min'], axis=1, inplace=True)
df.drop(columns=['kw_max_max'], axis=1, inplace=True)
df.drop(columns=['n_non_stop_words'], axis=1, inplace=True)

# %%
# 반올림 값을 확인하기 위해 만들었던 n_non_stop_words_rounded도 삭제
df.drop(columns=['n_non_stop_words_rounded'], axis=1, inplace=True)

# %%
# 'id'는 학습에 사용할 값이 아니므로 삭제한다
df.drop(columns=['id'], axis=1, inplace=True)

# %%
# 요일별 shares의 평균, 최댓값, 최솟값
weekday_stats = df.groupby('weekday')['shares'].agg(
    avg_shares=lambda x: round(x.mean(), 2),
    max_shares='max',
    min_shares='min'
).reset_index()

weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_stats['weekday'] = pd.Categorical(weekday_stats['weekday'], categories=weekday_order, ordered=True)
weekday_stats = weekday_stats.sort_values('weekday')
print(weekday_stats)
# Out:
#      weekday  avg_shares  max_shares  min_shares
# 1     Monday     3574.82      652900          43
# 5    Tuesday     3139.31      208300          42
# 6  Wednesday     3432.23      843300          48
# 4   Thursday     3225.35      298400          22
# 0     Friday     3152.97      233400          28
# 2   Saturday     4544.41      617900          49
# 3     Sunday     3937.87       83300         171

# %%
# 결측치 처리
for col in df.columns:
    if df[col].dtype == 'object': # 범주형 → 최빈값
        df[col].fillna(df[col].mode()[0], inplace=True)
    else: # 숫자형 → 중간값
        df[col].fillna(df[col].median(), inplace=True)
# Out:
# <ipython-input-14-6a0114ce1937>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# <ipython-input-14-6a0114ce1937>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
# is_weekend 변수 추가
df['is_weekend'] = df['weekday'].isin(['Saturday', 'Sunday']).astype(int)

# 범주형 데이터 One-Hot Encoding
df = pd.get_dummies(df, columns=['data_channel', 'weekday'], drop_first=True)

# %%
# 입력 변수(X), 라벨(y) 분리
X = df.drop(columns=['shares', 'y'])
y = np.log1p(df['shares'])  # log(1 + shares) -> shares=0 일 경우 에러 방지

# 정규화
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# train, val set을 나눈 뒤에 정규화 진행해보자.

# %% [markdown]
# # **Forward Selection**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %% [markdown]
# ## 정규화

# %%
# PCA 중요도 순서대로 feature가 담긴 list 저장
# ("preprocessing_v0 (1).ipynb" 마지막 셀의 출력 결과 복사, 붙여넣기)
important_features_ranked_index = [
 'data_channel_Lifestyle',
 'kw_avg_max',
 'global_rate_positive_words',
 'kw_min_avg',
 'data_channel_World',
 'min_positive_polarity',
 'LDA_00',
 'min_negative_polarity',
 'num_hrefs',
 'LDA_02',
 'global_rate_negative_words',
 'self_reference_min_shares',
 'num_keywords',
 'data_channel_Tech',
 'LDA_01',
 'kw_max_avg',
 'self_reference_max_shares',
 'LDA_04',
 'LDA_03',
 'num_self_hrefs',
 'kw_max_min',
 'num_videos',
 'abs_title_sentiment_polarity',
 'rate_positive_words',
 'num_imgs',
 'global_sentiment_polarity',
 'kw_min_max',
 'self_reference_avg_sharess',
 'data_channel_Entertainment',
 'max_negative_polarity',
 'average_token_length',
 'title_subjectivity',
 'data_channel_Social Media',
 'abs_title_subjectivity',
 'kw_avg_min',
 'n_non_stop_unique_tokens',
 'kw_avg_avg',
 'avg_negative_polarity',
 'rate_negative_words',
 'max_positive_polarity',
 'n_tokens_title',
 'n_unique_tokens',
 'avg_positive_polarity',
 'n_tokens_content',
 'title_sentiment_polarity',
 'weekday_Saturday',
 'weekday_Sunday',
 'is_weekend',
 'global_subjectivity',
 'weekday_Thursday',
 'weekday_Monday',
 'weekday_Tuesday',
 'weekday_Wednesday']

# %%
# train, val set 나누기
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
# 정규화
scaler = StandardScaler()

# 학습 데이터에 scaler를 fit, transform
X_train_scaled_array = scaler.fit_transform(X_train)
# list를 이용해 feature을 선택할 수 있게끔 하기 위해서 pandas DataFrame으로 수정
X_train_scaled = pd.DataFrame(X_train_scaled_array, columns=important_features_ranked_index, index=X_train.index)

# 학습 데이터에 맞게 fit된 scaler로 검증 데이터를 transform
X_val_scaled_array = scaler.transform(X_val)
# list를 이용해 feature을 선택할 수 있게끔 하기 위해서 pandas DataFrame으로 수정
X_val_scaled = pd.DataFrame(X_val_scaled_array, columns=important_features_ranked_index, index=X_val.index)

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# #### **fixed_optional_split**: 고정 리스트와 선택 리스트 만들기

# %% [markdown]
# PCA 중요도 순위에서 몇 순위까지 고정하고 싶은지 바꾸고 싶을 때 사용한다. <br>
# forward 함수를 호출하기 전에 사용해서, <br>
# 이 함수의 리턴값을 저장해서(fixed_features, optional_features) forward에 인수로 넣어주면 된다.

# %%
# 고정 리스트와 선택 리스트 만드는 함수 정의
def fixed_optional_split(fixed_num):
    # 고정된 리스트: 고정 개수만큼, PCA 중요도 순서대로 저장
    fixed = important_features_ranked_index[:fixed_num]

    # 선택을 위한 리스트: 나머지를 저장
    optional = important_features_ranked_index[fixed_num:]

    return fixed, optional

# %%
fixed_features = []
optional_features = []

# %%
# 다음과 같이 사용
fixed_features, optional_features = fixed_optional_split(20)

# %%
# 잘 들어갔는지 확인해보는 코드
fixed_features == important_features_ranked_index[:20]
# Out:
# True

# %% [markdown]
# #### **adjusted_r2**: Adjusted R^2를 계산하기

# %% [markdown]
# RidgePerf(성능 지표를 리턴하는 함수)의 내부에서 사용할 함수. <br>
# - R2: R2 값 <br>
# - N: number of examples (of validation set) (즉, 행의 수) <br>
# - P: number of input variables(features) (of validation set) (즉, 열의 수)

# %%
# R2값을 이용해 Adjusted R2를 계산하는 함수 adjusted_r2 정의
def adjusted_r2(R2, N, P):
    return 1 - (((1 - R2) * (N - 1)) / (N - P - 1))

# %% [markdown]
# #### **RidgePerf**: Ridge regression 모델을 학습시키고 성능 지표(Adjusted R2)를 리턴 받기

# %% [markdown]
# train과 validation set을 인수로 주면, Adjusted R2 값을 리턴하는 함수. <br>
# - sklearn.linear_model 에서 import한 Ridge를 사용. <br>
# - alpha는 1을 사용. (결정 과정은 아래 'Ridge 파라미터(alpha) 값 테스트'부분 참고)
# - 나머지 인수들은 기본값.
# - sklearn.metrics에서 import한 r2_score과, 위에서 정의한 adjusted_r2 함수를 사용.

# %%
# Ridge 모델을 학습시키고 Adjusted R2 성능 지표를 리턴하는 함수 RidgePerf 정의
def RidgePerf(X_tr, X_vl, y_tr, y_vl, alpha=1):
    model = Ridge(alpha = alpha)
    model.fit(X_tr, y_tr)
    y_predict = model.predict(X_vl)
    r2 = r2_score(y_vl, y_predict)
    r2_adj = adjusted_r2(r2, X_vl.shape[0], X_vl.shape[1])
    # 성능 지표로 Adjusted R2 사용
    metric = r2_adj
    return metric

# %% [markdown]
# #### **forward**: forward selection을 수행하기

# %%
# 인수로 train set과 validation set, fixed_list(고정하고 싶은 feature 이름들), optional_list(하나씩 선택하고 싶은 feature 이름들)를 받는다.
# 이때 X_trn과 X_vld는 열 이름을 가진 판다스 데이터프레임이어야 한다. (feature를 일부만 선택하는 데에 열 이름을 담은 리스트를 사용하기 때문)
def forward(X_trn, X_vld, y_trn, y_vld, fixed_list, optional_list, alpha=1):
    print(f"고정 개수: {len(fixed_list)}")
    print(f"fixed_list: {fixed_list}")

    # fixed_list로만 학습한 성능 저장
    fixed_perf = RidgePerf(X_trn[fixed_list], X_vld[fixed_list], y_trn, y_vld, alpha=alpha)
    print(f"fixed_perf: {fixed_perf}")

    # 반복 및 성능 비교 시 사용할 변수 초기화
    test_list = fixed_list.copy()               # 성능을 테스트할 subset을 담을 test_list
    results = {}                                # 각 subset들의 성능을 담을 딕셔너리 results
    final_fixed_list = fixed_list.copy()        # 다음 forward 함수에 넘겨줄 고정 feature들이 담긴 리스트.
    final_optional_list = optional_list.copy()  # 다음 forward 함수에 넘겨줄 후보군 feature들이 담긴 리스트.

    # optional_list의 feature 이름을 하나씩 골라 추가하며 각각의 성능을 results에 저장
    for i in range(len(optional_list)):

        # test_list에 optional_list의 i번째 feature 이름을 추가
        test_list.append(optional_list[i])

        # 성능을 results 딕셔너리에 추가.
        # 이때 key는 optional_list의 i번째 feature 이름이고, value는 test(fixed + 선택된 feature)_list를 이용한 성능이다.
        test_list_perf = RidgePerf(X_trn[test_list],
                                   X_vld[test_list],
                                   y_trn,
                                   y_vld,
                                   alpha=alpha)
        results[optional_list[i]] = test_list_perf
        print(f"tested feature: {optional_list[i]} / test_list_perf: {test_list_perf}")

        # 다음 반복을 위해 test_list에 append했던 optional_list[i]를 제거 (즉, 마지막 값을 제거)
        test_list.pop()

    # 성능 비교
    best_optional_feature = max(results, key=results.get)
    best_optional_perf = results[best_optional_feature]
    if fixed_perf <= best_optional_perf:
        # fixed_list의 성능보다 낫거나 같은 성능을 내는 subset이 있을 때
        # (주의: metric이 클수록 성능이 좋다는 가정 하에 작동)
        # (성능이 그대로일 때에도 다음 forward selection을 진행함)
        print("성능 개선.", f"best_optional_feature: {best_optional_feature}", "//", f"best_optional_perf: {best_optional_perf}")

        # 다음 forward 함수 호출에 넣어줄 리스트들을 업데이트.
        final_fixed_list.append(best_optional_feature)
        final_optional_list.remove(best_optional_feature)

        # forward(자기자신)를 호출. if문의 조건이 만족되지 않을 때까지 재귀적으로 호출된다.
        return forward(X_trn, X_vld, y_trn, y_vld, final_fixed_list, final_optional_list)


    else:
        print("성능 개선 불가하므로 멈춤.")
        print(f"number of features: {len(final_fixed_list)}")
        print(f"fixed_perf: {fixed_perf} / best_optional_perf: {best_optional_perf}")
        # feature를 추가했을 때 성능이 더 떨어졌다면 추가하지 않은 리스트를 리턴.
        # 인수로 들어온 fixed_list를 그대로 호출하는 것과 같음.
        return final_fixed_list, fixed_perf

# %% [markdown]
# ## Ridge 파라미터(alpha) 값 테스트

# %%
# PCA 중요도 순위 중 제일 높은 n개를 사용하자

# %%
# 중요도(importance_score)가 0.1보다 큰 6개를 사용해보자
n = 9
fixed_features, _ = fixed_optional_split(n)
for i in range(11):
    r2_adj = RidgePerf(X_train_scaled[fixed_features],
                       X_val_scaled[fixed_features],
                       y_train,
                       y_val,
                       alpha = i/10)
    print("alpha=", i/10, " /// adjusted_r2 =", r2_adj)

# 실행 결과, alpha가 증가함에 따라 adjusted r2 값이 커지는 경향이 보인다.
# Out:
# alpha= 0.0  /// adjusted_r2 = 0.01585379439711032
# alpha= 0.1  /// adjusted_r2 = 0.015853800191722
# alpha= 0.2  /// adjusted_r2 = 0.015853805982466662
# alpha= 0.3  /// adjusted_r2 = 0.015853811769345194
# alpha= 0.4  /// adjusted_r2 = 0.015853817552358263
# alpha= 0.5  /// adjusted_r2 = 0.01585382333150598
# alpha= 0.6  /// adjusted_r2 = 0.01585382910678912
# alpha= 0.7  /// adjusted_r2 = 0.01585383487820824
# alpha= 0.8  /// adjusted_r2 = 0.015853840645763784
# alpha= 0.9  /// adjusted_r2 = 0.01585384640945675
# alpha= 1.0  /// adjusted_r2 = 0.015853852169287252

# %%
# 중요도 시각화에서 큰 감소가 보이는 숫자는 13, 21, 31로 보이므로 이를 활용해보자

# %%
n = 13
fixed_features, _ = fixed_optional_split(n)
for i in range(11):
    r2_adj = RidgePerf(X_train_scaled[fixed_features],
                       X_val_scaled[fixed_features],
                       y_train,
                       y_val,
                       alpha = i/10)
    print("alpha=", i/10, " /// adjusted_r2 =", r2_adj)

# 실행 결과, alpha가 증가함에 따라 adjusted r2 값이 커지는 경향이 보인다.
# Out:
# alpha= 0.0  /// adjusted_r2 = 0.019946312595527593
# alpha= 0.1  /// adjusted_r2 = 0.019946313577122732
# alpha= 0.2  /// adjusted_r2 = 0.019946314554691202
# alpha= 0.3  /// adjusted_r2 = 0.019946315528234226
# alpha= 0.4  /// adjusted_r2 = 0.019946316497751804
# alpha= 0.5  /// adjusted_r2 = 0.019946317463244823
# alpha= 0.6  /// adjusted_r2 = 0.019946318424713838
# alpha= 0.7  /// adjusted_r2 = 0.019946319382159405
# alpha= 0.8  /// adjusted_r2 = 0.01994632033558208
# alpha= 0.9  /// adjusted_r2 = 0.019946321284982638
# alpha= 1.0  /// adjusted_r2 = 0.01994632223036108

# %%
n = 21
fixed_features, _ = fixed_optional_split(n)
for i in range(11):
    r2_adj = RidgePerf(X_train_scaled[fixed_features],
                       X_val_scaled[fixed_features],
                       y_train,
                       y_val,
                       alpha = i/10)
    print("alpha=", i/10, " /// adjusted_r2 =", r2_adj)

# 실행 결과, alpha가 증가함에 따라 adjusted r2 값이 커지는 경향이 보인다.
# Out:
# alpha= 0.0  /// adjusted_r2 = 0.06628259226249122
# alpha= 0.1  /// adjusted_r2 = 0.06628260843151501
# alpha= 0.2  /// adjusted_r2 = 0.06628262456553069
# alpha= 0.3  /// adjusted_r2 = 0.06628264066454503
# alpha= 0.4  /// adjusted_r2 = 0.06628265672856493
# alpha= 0.5  /// adjusted_r2 = 0.06628267275759792
# alpha= 0.6  /// adjusted_r2 = 0.06628268875165089
# alpha= 0.7  /// adjusted_r2 = 0.06628270471073039
# alpha= 0.8  /// adjusted_r2 = 0.06628272063484397
# alpha= 0.9  /// adjusted_r2 = 0.06628273652399852
# alpha= 1.0  /// adjusted_r2 = 0.0662827523782008

# %%
n = 31
fixed_features, _ = fixed_optional_split(n)
for i in range(11):
    r2_adj = RidgePerf(X_train_scaled[fixed_features],
                       X_val_scaled[fixed_features],
                       y_train,
                       y_val,
                       alpha = i/10)
    print("alpha=", i/10, " /// adjusted_r2 =", r2_adj)

# 실행 결과, alpha가 증가함에 따라 adjusted r2 값이 커지는 경향이 보인다.
# Out:
# alpha= 0.0  /// adjusted_r2 = 0.08209498637713775
# alpha= 0.1  /// adjusted_r2 = 0.08209502354131215
# alpha= 0.2  /// adjusted_r2 = 0.08209506067391292
# alpha= 0.3  /// adjusted_r2 = 0.08209509777494661
# alpha= 0.4  /// adjusted_r2 = 0.08209513484441999
# alpha= 0.5  /// adjusted_r2 = 0.08209517188233939
# alpha= 0.6  /// adjusted_r2 = 0.08209520888871147
# alpha= 0.7  /// adjusted_r2 = 0.08209524586354267
# alpha= 0.8  /// adjusted_r2 = 0.08209528280683964
# alpha= 0.9  /// adjusted_r2 = 0.08209531971860873
# alpha= 1.0  /// adjusted_r2 = 0.0820953565988567

# %% [markdown]
# -> 위의 실행 결과에 따라 Ridge regression에서 alpha를 기본값(1)로 두고 Forward Selection을 진행한다.

# %% [markdown]
# ## Forward Selection 진행하기

# %%
# 고정 리스트, 선택 리스트 만들기
# PCA 중요도 순위 중 높은 순위 N개를 고정하고 forward selection을 진행하는 코드.
N = 31
fixed_features, optional_features = fixed_optional_split(N)

# forward selection 진행하기
# 맨 마지막 return 값은 선택된 subset과 그 성능이다.
forward(X_train_scaled,
        X_val_scaled,
        y_train,
        y_val,
        fixed_features,
        optional_features)
# Out:
# 고정 개수: 31
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length']
# fixed_perf: 0.0820953565988567
# tested feature: title_subjectivity / test_list_perf: 0.0816280319965963
# tested feature: data_channel_Social Media / test_list_perf: 0.08196647824865444
# tested feature: abs_title_subjectivity / test_list_perf: 0.08188628328406788
# tested feature: kw_avg_min / test_list_perf: 0.08165223521372988
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.08198162648861052
# tested feature: kw_avg_avg / test_list_perf: 0.08158808472722645
# tested feature: avg_negative_polarity / test_list_perf: 0.08224816102242871
# tested feature: rate_negative_words / test_list_perf: 0.08232238764221378
# tested feature: max_positive_polarity / test_list_perf: 0.08188678272047722
# tested feature: n_tokens_title / test_list_perf: 0.08229932605503776
# tested feature: n_unique_tokens / test_list_perf: 0.0946355491274814
# tested feature: avg_positive_polarity / test_list_perf: 0.08314034301816187
# tested feature: n_tokens_content / test_list_perf: 0.08218035945996405
# tested feature: title_sentiment_polarity / test_list_perf: 0.08789413607803276
# tested feature: weekday_Saturday / test_list_perf: 0.08377783871900502
# tested feature: weekday_Sunday / test_list_perf: 0.08283241736747615
# tested feature: is_weekend / test_list_perf: 0.08205238525704506
# tested feature: global_subjectivity / test_list_perf: 0.08825322297650462
# tested feature: weekday_Thursday / test_list_perf: 0.08736817587925094
# tested feature: weekday_Monday / test_list_perf: 0.08201007043977959
# tested feature: weekday_Tuesday / test_list_perf: 0.08237306977274728
# tested feature: weekday_Wednesday / test_list_perf: 0.08271680905415824
# 성능 개선. best_optional_feature: n_unique_tokens // best_optional_perf: 0.0946355491274814
# 고정 개수: 32
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens']
# fixed_perf: 0.0946355491274814
# tested feature: title_subjectivity / test_list_perf: 0.09417800311622715
# tested feature: data_channel_Social Media / test_list_perf: 0.0946128738258949
# tested feature: abs_title_subjectivity / test_list_perf: 0.09441772389259817
# tested feature: kw_avg_min / test_list_perf: 0.09417614221733095
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.09448331560384926
# tested feature: kw_avg_avg / test_list_perf: 0.09414866203877714
# tested feature: avg_negative_polarity / test_list_perf: 0.09472749559852722
# tested feature: rate_negative_words / test_list_perf: 0.09478060965261459
# tested feature: max_positive_polarity / test_list_perf: 0.09450020813658566
# tested feature: n_tokens_title / test_list_perf: 0.09473930152444165
# tested feature: avg_positive_polarity / test_list_perf: 0.0957435762861154
# tested feature: n_tokens_content / test_list_perf: 0.09481484394435846
# tested feature: title_sentiment_polarity / test_list_perf: 0.10016926606766774
# tested feature: weekday_Saturday / test_list_perf: 0.09636289572176071
# tested feature: weekday_Sunday / test_list_perf: 0.09545702367106534
# tested feature: is_weekend / test_list_perf: 0.09414620435608068
# tested feature: global_subjectivity / test_list_perf: 0.09445178585807712
# tested feature: weekday_Thursday / test_list_perf: 0.09445182394665652
# tested feature: weekday_Monday / test_list_perf: 0.09430935859998346
# tested feature: weekday_Tuesday / test_list_perf: 0.09429000621548989
# tested feature: weekday_Wednesday / test_list_perf: 0.09443283823679927
# 성능 개선. best_optional_feature: title_sentiment_polarity // best_optional_perf: 0.10016926606766774
# 고정 개수: 33
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity']
# fixed_perf: 0.10016926606766774
# tested feature: title_subjectivity / test_list_perf: 0.09974748635165254
# tested feature: data_channel_Social Media / test_list_perf: 0.10008212455287291
# tested feature: abs_title_subjectivity / test_list_perf: 0.09995363740821994
# tested feature: kw_avg_min / test_list_perf: 0.09970476685884022
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10000679826519032
# tested feature: kw_avg_avg / test_list_perf: 0.09969435744750088
# tested feature: avg_negative_polarity / test_list_perf: 0.10026387737414388
# tested feature: rate_negative_words / test_list_perf: 0.10019297955044693
# tested feature: max_positive_polarity / test_list_perf: 0.10004529901897596
# tested feature: n_tokens_title / test_list_perf: 0.10028067556101672
# tested feature: avg_positive_polarity / test_list_perf: 0.10080162968103723
# tested feature: n_tokens_content / test_list_perf: 0.10087084489963816
# tested feature: weekday_Saturday / test_list_perf: 0.10255335064091187
# tested feature: weekday_Sunday / test_list_perf: 0.10032971920117417
# tested feature: is_weekend / test_list_perf: 0.09968864683674317
# tested feature: global_subjectivity / test_list_perf: 0.0999688162169825
# tested feature: weekday_Thursday / test_list_perf: 0.09996886998238808
# tested feature: weekday_Monday / test_list_perf: 0.09982685375501055
# tested feature: weekday_Tuesday / test_list_perf: 0.09989797118719346
# tested feature: weekday_Wednesday / test_list_perf: 0.09996539038893659
# 성능 개선. best_optional_feature: weekday_Saturday // best_optional_perf: 0.10255335064091187
# 고정 개수: 34
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday']
# fixed_perf: 0.10255335064091187
# tested feature: title_subjectivity / test_list_perf: 0.10214841940033548
# tested feature: data_channel_Social Media / test_list_perf: 0.10249907456608331
# tested feature: abs_title_subjectivity / test_list_perf: 0.10232434234796028
# tested feature: kw_avg_min / test_list_perf: 0.10211380109882806
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10243490409308653
# tested feature: kw_avg_avg / test_list_perf: 0.10207596349363868
# tested feature: avg_negative_polarity / test_list_perf: 0.10267379664758369
# tested feature: rate_negative_words / test_list_perf: 0.10256024796221341
# tested feature: max_positive_polarity / test_list_perf: 0.10244161708770572
# tested feature: n_tokens_title / test_list_perf: 0.10270033647468957
# tested feature: avg_positive_polarity / test_list_perf: 0.10286056272897781
# tested feature: n_tokens_content / test_list_perf: 0.10452421009158797
# tested feature: weekday_Sunday / test_list_perf: 0.10230017173193173
# tested feature: is_weekend / test_list_perf: 0.10207213213855659
# tested feature: global_subjectivity / test_list_perf: 0.10233933744223644
# tested feature: weekday_Thursday / test_list_perf: 0.1023394100125925
# tested feature: weekday_Monday / test_list_perf: 0.10221620257681885
# tested feature: weekday_Tuesday / test_list_perf: 0.10228504147842465
# tested feature: weekday_Wednesday / test_list_perf: 0.10235239604780055
# 성능 개선. best_optional_feature: n_tokens_content // best_optional_perf: 0.10452421009158797
# 고정 개수: 35
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content']
# fixed_perf: 0.10452421009158797
# tested feature: title_subjectivity / test_list_perf: 0.10405779613599553
# tested feature: data_channel_Social Media / test_list_perf: 0.10452017428642368
# tested feature: abs_title_subjectivity / test_list_perf: 0.10427885364082934
# tested feature: kw_avg_min / test_list_perf: 0.10407331950475152
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10441985737437631
# tested feature: kw_avg_avg / test_list_perf: 0.1040409437556129
# tested feature: avg_negative_polarity / test_list_perf: 0.1046408370199452
# tested feature: rate_negative_words / test_list_perf: 0.10444208751667328
# tested feature: max_positive_polarity / test_list_perf: 0.10437743534085597
# tested feature: n_tokens_title / test_list_perf: 0.10464516399847346
# tested feature: avg_positive_polarity / test_list_perf: 0.1039738194563079
# tested feature: weekday_Sunday / test_list_perf: 0.10457751618669853
# tested feature: is_weekend / test_list_perf: 0.10402168989312899
# tested feature: global_subjectivity / test_list_perf: 0.10430334962388699
# tested feature: weekday_Thursday / test_list_perf: 0.10430342872526277
# tested feature: weekday_Monday / test_list_perf: 0.10420712480679184
# tested feature: weekday_Tuesday / test_list_perf: 0.10423754128182228
# tested feature: weekday_Wednesday / test_list_perf: 0.1043241446951898
# 성능 개선. best_optional_feature: n_tokens_title // best_optional_perf: 0.10464516399847346
# 고정 개수: 36
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title']
# fixed_perf: 0.10464516399847346
# tested feature: title_subjectivity / test_list_perf: 0.10418108032948359
# tested feature: data_channel_Social Media / test_list_perf: 0.10465617281773876
# tested feature: abs_title_subjectivity / test_list_perf: 0.10440257684746634
# tested feature: kw_avg_min / test_list_perf: 0.10416567817600786
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10452515937745432
# tested feature: kw_avg_avg / test_list_perf: 0.10415524158314293
# tested feature: avg_negative_polarity / test_list_perf: 0.10424138102422997
# tested feature: rate_negative_words / test_list_perf: 0.10422677797781588
# tested feature: max_positive_polarity / test_list_perf: 0.10477958236099227
# tested feature: avg_positive_polarity / test_list_perf: 0.10408797166629857
# tested feature: weekday_Sunday / test_list_perf: 0.10468361166288997
# tested feature: is_weekend / test_list_perf: 0.10414000948437374
# tested feature: global_subjectivity / test_list_perf: 0.10442729117120642
# tested feature: weekday_Thursday / test_list_perf: 0.10442736646373685
# tested feature: weekday_Monday / test_list_perf: 0.1043299432960344
# tested feature: weekday_Tuesday / test_list_perf: 0.10435958471386964
# tested feature: weekday_Wednesday / test_list_perf: 0.1044443312341704
# 성능 개선. best_optional_feature: max_positive_polarity // best_optional_perf: 0.10477958236099227
# 고정 개수: 37
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity']
# fixed_perf: 0.10477958236099227
# tested feature: title_subjectivity / test_list_perf: 0.10431604269480388
# tested feature: data_channel_Social Media / test_list_perf: 0.10478384419154185
# tested feature: abs_title_subjectivity / test_list_perf: 0.10453907122229433
# tested feature: kw_avg_min / test_list_perf: 0.10430321322634128
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.1046427987144446
# tested feature: kw_avg_avg / test_list_perf: 0.10428391086291411
# tested feature: avg_negative_polarity / test_list_perf: 0.10444419453233234
# tested feature: rate_negative_words / test_list_perf: 0.10440337080570194
# tested feature: avg_positive_polarity / test_list_perf: 0.10424425455992958
# tested feature: weekday_Sunday / test_list_perf: 0.10481977094985406
# tested feature: is_weekend / test_list_perf: 0.10427309932087736
# tested feature: global_subjectivity / test_list_perf: 0.10455771126465685
# tested feature: weekday_Thursday / test_list_perf: 0.10455779394235587
# tested feature: weekday_Monday / test_list_perf: 0.10446996803864128
# tested feature: weekday_Tuesday / test_list_perf: 0.10450809889981238
# tested feature: weekday_Wednesday / test_list_perf: 0.10457875653067372
# 성능 개선. best_optional_feature: weekday_Sunday // best_optional_perf: 0.10481977094985406
# 고정 개수: 38
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity', 'weekday_Sunday']
# fixed_perf: 0.10481977094985406
# tested feature: title_subjectivity / test_list_perf: 0.10436454277720553
# tested feature: data_channel_Social Media / test_list_perf: 0.10482444877176966
# tested feature: abs_title_subjectivity / test_list_perf: 0.10457547547964507
# tested feature: kw_avg_min / test_list_perf: 0.10435111627624849
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10469852502848875
# tested feature: kw_avg_avg / test_list_perf: 0.10432282835077189
# tested feature: avg_negative_polarity / test_list_perf: 0.10448487895717096
# tested feature: rate_negative_words / test_list_perf: 0.1044233756024745
# tested feature: avg_positive_polarity / test_list_perf: 0.10420742408740202
# tested feature: is_weekend / test_list_perf: 0.10432696601660463
# tested feature: global_subjectivity / test_list_perf: 0.10460687545923475
# tested feature: weekday_Thursday / test_list_perf: 0.10460694021183448
# tested feature: weekday_Monday / test_list_perf: 0.10451104012934331
# tested feature: weekday_Tuesday / test_list_perf: 0.10456706121934911
# tested feature: weekday_Wednesday / test_list_perf: 0.10461677069890629
# 성능 개선. best_optional_feature: data_channel_Social Media // best_optional_perf: 0.10482444877176966
# 고정 개수: 39
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity', 'weekday_Sunday', 'data_channel_Social Media']
# fixed_perf: 0.10482444877176966
# tested feature: title_subjectivity / test_list_perf: 0.10451101419458475
# tested feature: abs_title_subjectivity / test_list_perf: 0.10458441804702445
# tested feature: kw_avg_min / test_list_perf: 0.10432840120451248
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.1046856825100565
# tested feature: kw_avg_avg / test_list_perf: 0.10429936280717056
# tested feature: avg_negative_polarity / test_list_perf: 0.10450243025049555
# tested feature: rate_negative_words / test_list_perf: 0.10444099767269521
# tested feature: avg_positive_polarity / test_list_perf: 0.10420423396093725
# tested feature: is_weekend / test_list_perf: 0.1043271902183085
# tested feature: global_subjectivity / test_list_perf: 0.10461297752425713
# tested feature: weekday_Thursday / test_list_perf: 0.10461303772985064
# tested feature: weekday_Monday / test_list_perf: 0.10451268804801006
# tested feature: weekday_Tuesday / test_list_perf: 0.1045649632463106
# tested feature: weekday_Wednesday / test_list_perf: 0.10462232748412914
# 성능 개선 불가하므로 멈춤.
# number of features: 39
# fixed_perf: 0.10482444877176966 / best_optional_perf: 0.1046856825100565

# %% [markdown]
# #### N을 여러 개로 바꾸어 forward selection 진행하여, 가장 높은 성능의 subset을 골라보자.

# %%
# PCA 중요도가 가장 높은 1개, 중요도가 0.1보다 큰 6개, 중요도 시각화에서 큰 감소가 보이는 13, 21, 31개를 골라보았다.
# ('preprocessing_v0_(1).ipynb' 파일 참고)
Nlist = [1, 6, 13, 21, 31]

results_dict = {}

for j in Nlist:
    N = j
    fixed_features, optional_features = fixed_optional_split(N)

    got = forward(X_train_scaled,
                            X_val_scaled,
                            y_train,
                            y_val,
                            fixed_features,
                            optional_features)
    results_dict[N] = got
    print(f"N: {N} / got[1]: {got[1]}")

best_perf_subset = max(results_dict, key=lambda k: results_dict[k][1])
best_perf = results_dict[best_perf_subset]
print()
print(f"best_perf_subset = {best_perf_subset}")
print(f"best_perf[1] = {best_perf[1]}")
# Out:
# 고정 개수: 1
# fixed_list: ['data_channel_Lifestyle']
# fixed_perf: -0.00035176983956786145
# tested feature: kw_avg_max / test_list_perf: 0.0003270307623545188
# tested feature: global_rate_positive_words / test_list_perf: 0.0007194165781551076
# tested feature: kw_min_avg / test_list_perf: 0.0021745424777408484
# tested feature: data_channel_World / test_list_perf: 0.009917834723260133
# tested feature: min_positive_polarity / test_list_perf: 0.0004909364091028046
# tested feature: LDA_00 / test_list_perf: 0.005338243533250409
# tested feature: min_negative_polarity / test_list_perf: 0.0013225450295968333
# tested feature: num_hrefs / test_list_perf: 0.0010369895131850937
# tested feature: LDA_02 / test_list_perf: 0.003718000411115585
# tested feature: global_rate_negative_words / test_list_perf: 0.0018135177448214135
# tested feature: self_reference_min_shares / test_list_perf: 0.000899417896399135
# tested feature: num_keywords / test_list_perf: -0.0002853993807545585
# tested feature: data_channel_Tech / test_list_perf: 0.006011983038950119
# tested feature: LDA_01 / test_list_perf: 0.011145222494609142
# tested feature: kw_max_avg / test_list_perf: 0.011403784015573737
# tested feature: self_reference_max_shares / test_list_perf: 0.04810575588951749
# tested feature: LDA_04 / test_list_perf: 0.008850484849546647
# tested feature: LDA_03 / test_list_perf: 0.004088211377633044
# tested feature: num_self_hrefs / test_list_perf: 0.008379855193919483
# tested feature: kw_max_min / test_list_perf: 0.0010813732440866364
# tested feature: num_videos / test_list_perf: 0.0024338435727905283
# tested feature: abs_title_sentiment_polarity / test_list_perf: 0.027195850598343396
# tested feature: rate_positive_words / test_list_perf: 0.014429253685531163
# tested feature: num_imgs / test_list_perf: 0.0015554396381235458
# tested feature: global_sentiment_polarity / test_list_perf: 0.006066719942420695
# tested feature: kw_min_max / test_list_perf: 0.0022281046901965196
# tested feature: self_reference_avg_sharess / test_list_perf: 0.0019048943118503692
# tested feature: data_channel_Entertainment / test_list_perf: -0.0005309254070480218
# tested feature: max_negative_polarity / test_list_perf: -0.0005413941428347169
# tested feature: average_token_length / test_list_perf: 0.0024101141300749696
# tested feature: title_subjectivity / test_list_perf: 0.001130828770755432
# tested feature: data_channel_Social Media / test_list_perf: -0.00048599887614519943
# tested feature: abs_title_subjectivity / test_list_perf: 0.0007787698790443498
# tested feature: kw_avg_min / test_list_perf: -0.00024330606672284816
# tested feature: n_non_stop_unique_tokens / test_list_perf: 7.378300015070671e-05
# tested feature: kw_avg_avg / test_list_perf: -0.0010085652873337292
# tested feature: avg_negative_polarity / test_list_perf: 0.002036714887415303
# tested feature: rate_negative_words / test_list_perf: 0.0012406841198850938
# tested feature: max_positive_polarity / test_list_perf: -0.0006401876156443276
# tested feature: n_tokens_title / test_list_perf: 0.0023911620820042945
# tested feature: n_unique_tokens / test_list_perf: 0.016525002988078574
# tested feature: avg_positive_polarity / test_list_perf: 0.003050621293362976
# tested feature: n_tokens_content / test_list_perf: 0.018818495876887664
# tested feature: title_sentiment_polarity / test_list_perf: 0.006765504353802521
# tested feature: weekday_Saturday / test_list_perf: 0.001970720218931521
# tested feature: weekday_Sunday / test_list_perf: 0.01852799586405096
# tested feature: is_weekend / test_list_perf: -0.00018816089330919716
# tested feature: global_subjectivity / test_list_perf: 0.008616913835109541
# tested feature: weekday_Thursday / test_list_perf: 0.006350913054024687
# tested feature: weekday_Monday / test_list_perf: -0.0003616050936676718
# tested feature: weekday_Tuesday / test_list_perf: 0.0001458784607694108
# tested feature: weekday_Wednesday / test_list_perf: 0.00016357622080009904
# 성능 개선. best_optional_feature: self_reference_max_shares // best_optional_perf: 0.04810575588951749
# 고정 개수: 2
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares']
# fixed_perf: 0.04810575588951749
# tested feature: kw_avg_max / test_list_perf: 0.05004570412549314
# tested feature: global_rate_positive_words / test_list_perf: 0.04882832397196979
# tested feature: kw_min_avg / test_list_perf: 0.04899264927753488
# tested feature: data_channel_World / test_list_perf: 0.05408310831923113
# tested feature: min_positive_polarity / test_list_perf: 0.049228312577019984
# tested feature: LDA_00 / test_list_perf: 0.049439316519610865
# tested feature: min_negative_polarity / test_list_perf: 0.048132571395457346
# tested feature: num_hrefs / test_list_perf: 0.04807302200285368
# tested feature: LDA_02 / test_list_perf: 0.05162424240310626
# tested feature: global_rate_negative_words / test_list_perf: 0.048218137884495804
# tested feature: self_reference_min_shares / test_list_perf: 0.048057295468286854
# tested feature: num_keywords / test_list_perf: 0.048192379339662916
# tested feature: data_channel_Tech / test_list_perf: 0.04671159608782227
# tested feature: LDA_01 / test_list_perf: 0.048057961327035326
# tested feature: kw_max_avg / test_list_perf: 0.052313172878772574
# tested feature: LDA_04 / test_list_perf: 0.05250562228989608
# tested feature: LDA_03 / test_list_perf: 0.049601684215455744
# tested feature: num_self_hrefs / test_list_perf: 0.05122331510566669
# tested feature: kw_max_min / test_list_perf: 0.05036071062400249
# tested feature: num_videos / test_list_perf: 0.05091259967388839
# tested feature: abs_title_sentiment_polarity / test_list_perf: 0.06078625021810946
# tested feature: rate_positive_words / test_list_perf: 0.04891719327879618
# tested feature: num_imgs / test_list_perf: 0.05390330247329056
# tested feature: global_sentiment_polarity / test_list_perf: 0.05213130774761976
# tested feature: kw_min_max / test_list_perf: 0.0503226190286401
# tested feature: self_reference_avg_sharess / test_list_perf: 0.05032139998533891
# tested feature: data_channel_Entertainment / test_list_perf: 0.04803913101588542
# tested feature: max_negative_polarity / test_list_perf: 0.048710613969287775
# tested feature: average_token_length / test_list_perf: 0.05023031259238386
# tested feature: title_subjectivity / test_list_perf: 0.04892170762086223
# tested feature: data_channel_Social Media / test_list_perf: 0.04835602611594636
# tested feature: abs_title_subjectivity / test_list_perf: 0.04924625465158561
# tested feature: kw_avg_min / test_list_perf: 0.047546384836796296
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.0481929370880656
# tested feature: kw_avg_avg / test_list_perf: 0.04760853269767651
# tested feature: avg_negative_polarity / test_list_perf: 0.048989435935435366
# tested feature: rate_negative_words / test_list_perf: 0.04916269707001952
# tested feature: max_positive_polarity / test_list_perf: 0.04788122389159111
# tested feature: n_tokens_title / test_list_perf: 0.04935824704850489
# tested feature: n_unique_tokens / test_list_perf: 0.062362540852870185
# tested feature: avg_positive_polarity / test_list_perf: 0.05194460420349112
# tested feature: n_tokens_content / test_list_perf: 0.05100166785941396
# tested feature: title_sentiment_polarity / test_list_perf: 0.0551173595706933
# tested feature: weekday_Saturday / test_list_perf: 0.05448292580334768
# tested feature: weekday_Sunday / test_list_perf: 0.05775642521513591
# tested feature: is_weekend / test_list_perf: 0.04814744017096484
# tested feature: global_subjectivity / test_list_perf: 0.05577513561305991
# tested feature: weekday_Thursday / test_list_perf: 0.05365244481785991
# tested feature: weekday_Monday / test_list_perf: 0.04807465949387524
# tested feature: weekday_Tuesday / test_list_perf: 0.04845615788578883
# tested feature: weekday_Wednesday / test_list_perf: 0.04879726592971967
# 성능 개선. best_optional_feature: n_unique_tokens // best_optional_perf: 0.062362540852870185
# 고정 개수: 3
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens']
# fixed_perf: 0.062362540852870185
# tested feature: kw_avg_max / test_list_perf: 0.0637762637088618
# tested feature: global_rate_positive_words / test_list_perf: 0.06295432129182044
# tested feature: kw_min_avg / test_list_perf: 0.06306665401752343
# tested feature: data_channel_World / test_list_perf: 0.06695256197781463
# tested feature: min_positive_polarity / test_list_perf: 0.06303312431673469
# tested feature: LDA_00 / test_list_perf: 0.06327953567305167
# tested feature: min_negative_polarity / test_list_perf: 0.06252970290643589
# tested feature: num_hrefs / test_list_perf: 0.06237005054569367
# tested feature: LDA_02 / test_list_perf: 0.06474847820758145
# tested feature: global_rate_negative_words / test_list_perf: 0.06234105523886346
# tested feature: self_reference_min_shares / test_list_perf: 0.06210144784676219
# tested feature: num_keywords / test_list_perf: 0.06243439553953334
# tested feature: data_channel_Tech / test_list_perf: 0.0609819791998214
# tested feature: LDA_01 / test_list_perf: 0.06222821106416565
# tested feature: kw_max_avg / test_list_perf: 0.0662407605639338
# tested feature: LDA_04 / test_list_perf: 0.0669733313444495
# tested feature: LDA_03 / test_list_perf: 0.06393137065677135
# tested feature: num_self_hrefs / test_list_perf: 0.06571621702721675
# tested feature: kw_max_min / test_list_perf: 0.06510266571039092
# tested feature: num_videos / test_list_perf: 0.06507422897877546
# tested feature: abs_title_sentiment_polarity / test_list_perf: 0.07532958311182858
# tested feature: rate_positive_words / test_list_perf: 0.06295557689163644
# tested feature: num_imgs / test_list_perf: 0.06826200330538001
# tested feature: global_sentiment_polarity / test_list_perf: 0.06618725966377081
# tested feature: kw_min_max / test_list_perf: 0.06444716900959968
# tested feature: self_reference_avg_sharess / test_list_perf: 0.06437353690130632
# tested feature: data_channel_Entertainment / test_list_perf: 0.06233680357933791
# tested feature: max_negative_polarity / test_list_perf: 0.06301254082444496
# tested feature: average_token_length / test_list_perf: 0.06452257250621696
# tested feature: title_subjectivity / test_list_perf: 0.06298057247507594
# tested feature: data_channel_Social Media / test_list_perf: 0.06271139622293043
# tested feature: abs_title_subjectivity / test_list_perf: 0.06328718865844851
# tested feature: kw_avg_min / test_list_perf: 0.06169484989428253
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.06222100154351651
# tested feature: kw_avg_avg / test_list_perf: 0.0618652557763647
# tested feature: avg_negative_polarity / test_list_perf: 0.06307994464243627
# tested feature: rate_negative_words / test_list_perf: 0.06325719292465926
# tested feature: max_positive_polarity / test_list_perf: 0.062183288419901506
# tested feature: n_tokens_title / test_list_perf: 0.06335445831860775
# tested feature: avg_positive_polarity / test_list_perf: 0.06636135496583007
# tested feature: n_tokens_content / test_list_perf: 0.06506084525002287
# tested feature: title_sentiment_polarity / test_list_perf: 0.06905672697848053
# tested feature: weekday_Saturday / test_list_perf: 0.06879853207266895
# tested feature: weekday_Sunday / test_list_perf: 0.0724175579309666
# tested feature: is_weekend / test_list_perf: 0.061867549325267945
# tested feature: global_subjectivity / test_list_perf: 0.06227308505950402
# tested feature: weekday_Thursday / test_list_perf: 0.062273012976526765
# tested feature: weekday_Monday / test_list_perf: 0.06202189397530289
# tested feature: weekday_Tuesday / test_list_perf: 0.062052758692940246
# tested feature: weekday_Wednesday / test_list_perf: 0.06214985475819235
# 성능 개선. best_optional_feature: abs_title_sentiment_polarity // best_optional_perf: 0.07532958311182858
# 고정 개수: 4
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity']
# fixed_perf: 0.07532958311182858
# tested feature: kw_avg_max / test_list_perf: 0.07744133455290836
# tested feature: global_rate_positive_words / test_list_perf: 0.07667562244401005
# tested feature: kw_min_avg / test_list_perf: 0.07656572584545596
# tested feature: data_channel_World / test_list_perf: 0.08012528293990862
# tested feature: min_positive_polarity / test_list_perf: 0.07547535207576184
# tested feature: LDA_00 / test_list_perf: 0.07587812142057626
# tested feature: min_negative_polarity / test_list_perf: 0.07512964532724975
# tested feature: num_hrefs / test_list_perf: 0.07518823490877546
# tested feature: LDA_02 / test_list_perf: 0.07754112522450585
# tested feature: global_rate_negative_words / test_list_perf: 0.07507547801488934
# tested feature: self_reference_min_shares / test_list_perf: 0.07487360834537726
# tested feature: num_keywords / test_list_perf: 0.07539827283795375
# tested feature: data_channel_Tech / test_list_perf: 0.07394520586597808
# tested feature: LDA_01 / test_list_perf: 0.07528834465124445
# tested feature: kw_max_avg / test_list_perf: 0.07778398068928283
# tested feature: LDA_04 / test_list_perf: 0.07977610998846629
# tested feature: LDA_03 / test_list_perf: 0.07680806804661011
# tested feature: num_self_hrefs / test_list_perf: 0.0785561974331831
# tested feature: kw_max_min / test_list_perf: 0.07570926624660901
# tested feature: num_videos / test_list_perf: 0.08143698007822053
# tested feature: rate_positive_words / test_list_perf: 0.0750637546731503
# tested feature: num_imgs / test_list_perf: 0.07787737343169676
# tested feature: global_sentiment_polarity / test_list_perf: 0.07721316820178858
# tested feature: kw_min_max / test_list_perf: 0.07575184903767718
# tested feature: self_reference_avg_sharess / test_list_perf: 0.07560993730360399
# tested feature: data_channel_Entertainment / test_list_perf: 0.0752390051095847
# tested feature: max_negative_polarity / test_list_perf: 0.07521730321996789
# tested feature: average_token_length / test_list_perf: 0.07591714958769968
# tested feature: title_subjectivity / test_list_perf: 0.07530888102076816
# tested feature: data_channel_Social Media / test_list_perf: 0.07601410754321447
# tested feature: abs_title_subjectivity / test_list_perf: 0.07560595995633645
# tested feature: kw_avg_min / test_list_perf: 0.07469767130394012
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.07560181042214809
# tested feature: kw_avg_avg / test_list_perf: 0.07497899579546685
# tested feature: avg_negative_polarity / test_list_perf: 0.07581920472603165
# tested feature: rate_negative_words / test_list_perf: 0.07584723966844942
# tested feature: max_positive_polarity / test_list_perf: 0.07525210031583729
# tested feature: n_tokens_title / test_list_perf: 0.07593025299673173
# tested feature: avg_positive_polarity / test_list_perf: 0.08289515224458033
# tested feature: n_tokens_content / test_list_perf: 0.07622862534711883
# tested feature: title_sentiment_polarity / test_list_perf: 0.08188349106764958
# tested feature: weekday_Saturday / test_list_perf: 0.0789579494481959
# tested feature: weekday_Sunday / test_list_perf: 0.07658723690495617
# tested feature: is_weekend / test_list_perf: 0.074860773365234
# tested feature: global_subjectivity / test_list_perf: 0.07525269934232193
# tested feature: weekday_Thursday / test_list_perf: 0.0752526171883463
# tested feature: weekday_Monday / test_list_perf: 0.07498861399874279
# tested feature: weekday_Tuesday / test_list_perf: 0.07503119116919155
# tested feature: weekday_Wednesday / test_list_perf: 0.07511252774258781
# 성능 개선. best_optional_feature: avg_positive_polarity // best_optional_perf: 0.08289515224458033
# 고정 개수: 5
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity']
# fixed_perf: 0.08289515224458033
# tested feature: kw_avg_max / test_list_perf: 0.08574674753679723
# tested feature: global_rate_positive_words / test_list_perf: 0.08429149904009436
# tested feature: kw_min_avg / test_list_perf: 0.08415575334704917
# tested feature: data_channel_World / test_list_perf: 0.08789066148731306
# tested feature: min_positive_polarity / test_list_perf: 0.08307243868665015
# tested feature: LDA_00 / test_list_perf: 0.0838410136257387
# tested feature: min_negative_polarity / test_list_perf: 0.08339520996642036
# tested feature: num_hrefs / test_list_perf: 0.08278119513679671
# tested feature: LDA_02 / test_list_perf: 0.08454724726166496
# tested feature: global_rate_negative_words / test_list_perf: 0.08269603270211845
# tested feature: self_reference_min_shares / test_list_perf: 0.08266662186917395
# tested feature: num_keywords / test_list_perf: 0.08289150832347136
# tested feature: data_channel_Tech / test_list_perf: 0.08140543001005374
# tested feature: LDA_01 / test_list_perf: 0.08283673251954082
# tested feature: kw_max_avg / test_list_perf: 0.0850805322051732
# tested feature: LDA_04 / test_list_perf: 0.08687953417006566
# tested feature: LDA_03 / test_list_perf: 0.08423111232887259
# tested feature: num_self_hrefs / test_list_perf: 0.08577168876321206
# tested feature: kw_max_min / test_list_perf: 0.08221047310129748
# tested feature: num_videos / test_list_perf: 0.08402733755306935
# tested feature: rate_positive_words / test_list_perf: 0.0828543241312708
# tested feature: num_imgs / test_list_perf: 0.08334702149989004
# tested feature: global_sentiment_polarity / test_list_perf: 0.0849546731136892
# tested feature: kw_min_max / test_list_perf: 0.08294641796853408
# tested feature: self_reference_avg_sharess / test_list_perf: 0.08313171198451397
# tested feature: data_channel_Entertainment / test_list_perf: 0.0826798708347789
# tested feature: max_negative_polarity / test_list_perf: 0.08266450763013389
# tested feature: average_token_length / test_list_perf: 0.08298520783695496
# tested feature: title_subjectivity / test_list_perf: 0.08301751178843908
# tested feature: data_channel_Social Media / test_list_perf: 0.08368312440793424
# tested feature: abs_title_subjectivity / test_list_perf: 0.08346102335653904
# tested feature: kw_avg_min / test_list_perf: 0.08252821850218073
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.08395596076208989
# tested feature: kw_avg_avg / test_list_perf: 0.082511441857269
# tested feature: avg_negative_polarity / test_list_perf: 0.08352171335334024
# tested feature: rate_negative_words / test_list_perf: 0.08315927291932312
# tested feature: max_positive_polarity / test_list_perf: 0.08278180667653823
# tested feature: n_tokens_title / test_list_perf: 0.08358874712482156
# tested feature: n_tokens_content / test_list_perf: 0.08260245624538876
# tested feature: title_sentiment_polarity / test_list_perf: 0.08814436729156949
# tested feature: weekday_Saturday / test_list_perf: 0.08440321378259052
# tested feature: weekday_Sunday / test_list_perf: 0.08632966288119881
# tested feature: is_weekend / test_list_perf: 0.0824387903479381
# tested feature: global_subjectivity / test_list_perf: 0.0827796816221551
# tested feature: weekday_Thursday / test_list_perf: 0.0827796034739019
# tested feature: weekday_Monday / test_list_perf: 0.08256247819126539
# tested feature: weekday_Tuesday / test_list_perf: 0.08265074955252627
# tested feature: weekday_Wednesday / test_list_perf: 0.08268644318789631
# 성능 개선. best_optional_feature: title_sentiment_polarity // best_optional_perf: 0.08814436729156949
# 고정 개수: 6
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity']
# fixed_perf: 0.08814436729156949
# tested feature: kw_avg_max / test_list_perf: 0.09067678586179428
# tested feature: global_rate_positive_words / test_list_perf: 0.0895882464971055
# tested feature: kw_min_avg / test_list_perf: 0.08943422957175828
# tested feature: data_channel_World / test_list_perf: 0.09263980032087415
# tested feature: min_positive_polarity / test_list_perf: 0.08804730965088126
# tested feature: LDA_00 / test_list_perf: 0.08906905115307007
# tested feature: min_negative_polarity / test_list_perf: 0.08858025437273931
# tested feature: num_hrefs / test_list_perf: 0.0880643222997819
# tested feature: LDA_02 / test_list_perf: 0.09030738145707629
# tested feature: global_rate_negative_words / test_list_perf: 0.0879132213466407
# tested feature: self_reference_min_shares / test_list_perf: 0.08795452962748385
# tested feature: num_keywords / test_list_perf: 0.08822604931982858
# tested feature: data_channel_Tech / test_list_perf: 0.08665843082374236
# tested feature: LDA_01 / test_list_perf: 0.0880528225969257
# tested feature: kw_max_avg / test_list_perf: 0.09015613813355694
# tested feature: LDA_04 / test_list_perf: 0.09203738659422556
# tested feature: LDA_03 / test_list_perf: 0.0893621336886744
# tested feature: num_self_hrefs / test_list_perf: 0.09091746815409463
# tested feature: kw_max_min / test_list_perf: 0.08728070045689851
# tested feature: num_videos / test_list_perf: 0.08916734663975534
# tested feature: rate_positive_words / test_list_perf: 0.08810830093214284
# tested feature: num_imgs / test_list_perf: 0.08911485150001164
# tested feature: global_sentiment_polarity / test_list_perf: 0.08998723163680744
# tested feature: kw_min_max / test_list_perf: 0.08810014949973888
# tested feature: self_reference_avg_sharess / test_list_perf: 0.08816907272569974
# tested feature: data_channel_Entertainment / test_list_perf: 0.08793809171432121
# tested feature: max_negative_polarity / test_list_perf: 0.08789223303809368
# tested feature: average_token_length / test_list_perf: 0.08812545911070413
# tested feature: title_subjectivity / test_list_perf: 0.08824228480441654
# tested feature: data_channel_Social Media / test_list_perf: 0.08867736374666924
# tested feature: abs_title_subjectivity / test_list_perf: 0.08861310962714763
# tested feature: kw_avg_min / test_list_perf: 0.08772532243414899
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.08906690357445601
# tested feature: kw_avg_avg / test_list_perf: 0.08777766538598275
# tested feature: avg_negative_polarity / test_list_perf: 0.08875651180025745
# tested feature: rate_negative_words / test_list_perf: 0.08823596130166911
# tested feature: max_positive_polarity / test_list_perf: 0.0880394805423178
# tested feature: n_tokens_title / test_list_perf: 0.08880334985936378
# tested feature: n_tokens_content / test_list_perf: 0.08838488818654755
# tested feature: weekday_Saturday / test_list_perf: 0.09065317868913991
# tested feature: weekday_Sunday / test_list_perf: 0.09007438963552883
# tested feature: is_weekend / test_list_perf: 0.08769410288123691
# tested feature: global_subjectivity / test_list_perf: 0.08800422545576292
# tested feature: weekday_Thursday / test_list_perf: 0.08800417039796193
# tested feature: weekday_Monday / test_list_perf: 0.08780753382159134
# tested feature: weekday_Tuesday / test_list_perf: 0.08795610711788648
# tested feature: weekday_Wednesday / test_list_perf: 0.08793757963880422
# 성능 개선. best_optional_feature: data_channel_World // best_optional_perf: 0.09263980032087415
# 고정 개수: 7
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World']
# fixed_perf: 0.09263980032087415
# tested feature: kw_avg_max / test_list_perf: 0.09308848501014233
# tested feature: global_rate_positive_words / test_list_perf: 0.09346957829841762
# tested feature: kw_min_avg / test_list_perf: 0.0933696719369227
# tested feature: min_positive_polarity / test_list_perf: 0.09222897878160563
# tested feature: LDA_00 / test_list_perf: 0.09240877656634705
# tested feature: min_negative_polarity / test_list_perf: 0.09268048308986931
# tested feature: num_hrefs / test_list_perf: 0.09310494864337437
# tested feature: LDA_02 / test_list_perf: 0.09394875744216913
# tested feature: global_rate_negative_words / test_list_perf: 0.09242499366250878
# tested feature: self_reference_min_shares / test_list_perf: 0.09245615682080821
# tested feature: num_keywords / test_list_perf: 0.0926368843323011
# tested feature: data_channel_Tech / test_list_perf: 0.09120796366302186
# tested feature: LDA_01 / test_list_perf: 0.09255395412399237
# tested feature: kw_max_avg / test_list_perf: 0.09452777972395021
# tested feature: LDA_04 / test_list_perf: 0.09677983683317326
# tested feature: LDA_03 / test_list_perf: 0.09352720418094262
# tested feature: num_self_hrefs / test_list_perf: 0.09536504722302896
# tested feature: kw_max_min / test_list_perf: 0.0918656639027593
# tested feature: num_videos / test_list_perf: 0.09342532665357672
# tested feature: rate_positive_words / test_list_perf: 0.0925029305611954
# tested feature: num_imgs / test_list_perf: 0.09371097039678944
# tested feature: global_sentiment_polarity / test_list_perf: 0.09368632153748613
# tested feature: kw_min_max / test_list_perf: 0.09244311758536627
# tested feature: self_reference_avg_sharess / test_list_perf: 0.09256144569454205
# tested feature: data_channel_Entertainment / test_list_perf: 0.09243566051023933
# tested feature: max_negative_polarity / test_list_perf: 0.09235626305666278
# tested feature: average_token_length / test_list_perf: 0.09279968124093607
# tested feature: title_subjectivity / test_list_perf: 0.09235152870104013
# tested feature: data_channel_Social Media / test_list_perf: 0.09287576747996762
# tested feature: abs_title_subjectivity / test_list_perf: 0.09247773214576105
# tested feature: kw_avg_min / test_list_perf: 0.0920912907205611
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.09275802096086094
# tested feature: kw_avg_avg / test_list_perf: 0.09216766792090503
# tested feature: avg_negative_polarity / test_list_perf: 0.09308559187905896
# tested feature: rate_negative_words / test_list_perf: 0.09268670389197131
# tested feature: max_positive_polarity / test_list_perf: 0.09253678505753438
# tested feature: n_tokens_title / test_list_perf: 0.0931244027118664
# tested feature: n_tokens_content / test_list_perf: 0.09268231247439884
# tested feature: weekday_Saturday / test_list_perf: 0.09541776016401093
# tested feature: weekday_Sunday / test_list_perf: 0.0945207689064177
# tested feature: is_weekend / test_list_perf: 0.09219011741258476
# tested feature: global_subjectivity / test_list_perf: 0.0924687106232096
# tested feature: weekday_Thursday / test_list_perf: 0.09246871154229819
# tested feature: weekday_Monday / test_list_perf: 0.09231132614478443
# tested feature: weekday_Tuesday / test_list_perf: 0.09242028596121576
# tested feature: weekday_Wednesday / test_list_perf: 0.09243570845518134
# 성능 개선. best_optional_feature: LDA_04 // best_optional_perf: 0.09677983683317326
# 고정 개수: 8
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04']
# fixed_perf: 0.09677983683317326
# tested feature: kw_avg_max / test_list_perf: 0.09729260197322498
# tested feature: global_rate_positive_words / test_list_perf: 0.0978892233627856
# tested feature: kw_min_avg / test_list_perf: 0.09777271831106527
# tested feature: min_positive_polarity / test_list_perf: 0.09632425963127489
# tested feature: LDA_00 / test_list_perf: 0.09653996144636856
# tested feature: min_negative_polarity / test_list_perf: 0.09683839677826511
# tested feature: num_hrefs / test_list_perf: 0.09745482017952656
# tested feature: LDA_02 / test_list_perf: 0.098110800610122
# tested feature: global_rate_negative_words / test_list_perf: 0.09653945615162474
# tested feature: self_reference_min_shares / test_list_perf: 0.09647397492120657
# tested feature: num_keywords / test_list_perf: 0.09678087275711944
# tested feature: data_channel_Tech / test_list_perf: 0.0953306326067277
# tested feature: LDA_01 / test_list_perf: 0.09672771985181083
# tested feature: kw_max_avg / test_list_perf: 0.09887134979180234
# tested feature: LDA_03 / test_list_perf: 0.09663444446136682
# tested feature: num_self_hrefs / test_list_perf: 0.09670916287944464
# tested feature: kw_max_min / test_list_perf: 0.09599326514397022
# tested feature: num_videos / test_list_perf: 0.09757222986698166
# tested feature: rate_positive_words / test_list_perf: 0.09667074839231415
# tested feature: num_imgs / test_list_perf: 0.09784665708311902
# tested feature: global_sentiment_polarity / test_list_perf: 0.09760633772869576
# tested feature: kw_min_max / test_list_perf: 0.09659262335018082
# tested feature: self_reference_avg_sharess / test_list_perf: 0.09670844666949774
# tested feature: data_channel_Entertainment / test_list_perf: 0.09657569032286428
# tested feature: max_negative_polarity / test_list_perf: 0.09653733048552526
# tested feature: average_token_length / test_list_perf: 0.09700815560572584
# tested feature: title_subjectivity / test_list_perf: 0.0964855461101144
# tested feature: data_channel_Social Media / test_list_perf: 0.09708702747295839
# tested feature: abs_title_subjectivity / test_list_perf: 0.09660906076425779
# tested feature: kw_avg_min / test_list_perf: 0.09614660038802603
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.09685140481699417
# tested feature: kw_avg_avg / test_list_perf: 0.09637183831919383
# tested feature: avg_negative_polarity / test_list_perf: 0.09720864376794647
# tested feature: rate_negative_words / test_list_perf: 0.09686031263197914
# tested feature: max_positive_polarity / test_list_perf: 0.0966641735538305
# tested feature: n_tokens_title / test_list_perf: 0.09729856079664989
# tested feature: n_tokens_content / test_list_perf: 0.09682970611307751
# tested feature: weekday_Saturday / test_list_perf: 0.09949071713495128
# tested feature: weekday_Sunday / test_list_perf: 0.0986639046019765
# tested feature: is_weekend / test_list_perf: 0.09633249937248989
# tested feature: global_subjectivity / test_list_perf: 0.09661368308323082
# tested feature: weekday_Thursday / test_list_perf: 0.09661367848294411
# tested feature: weekday_Monday / test_list_perf: 0.09645106661526492
# tested feature: weekday_Tuesday / test_list_perf: 0.09656593073002417
# tested feature: weekday_Wednesday / test_list_perf: 0.09657797125497036
# 성능 개선. best_optional_feature: weekday_Saturday // best_optional_perf: 0.09949071713495128
# 고정 개수: 9
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday']
# fixed_perf: 0.09949071713495128
# tested feature: kw_avg_max / test_list_perf: 0.09984231595867288
# tested feature: global_rate_positive_words / test_list_perf: 0.10049653132716863
# tested feature: kw_min_avg / test_list_perf: 0.10046710402074399
# tested feature: min_positive_polarity / test_list_perf: 0.09923282218924401
# tested feature: LDA_00 / test_list_perf: 0.09916887793652729
# tested feature: min_negative_polarity / test_list_perf: 0.0997061285318126
# tested feature: num_hrefs / test_list_perf: 0.10018354917870054
# tested feature: LDA_02 / test_list_perf: 0.10036518366816516
# tested feature: global_rate_negative_words / test_list_perf: 0.09932835832961695
# tested feature: self_reference_min_shares / test_list_perf: 0.09930343643124984
# tested feature: num_keywords / test_list_perf: 0.09943559359582532
# tested feature: data_channel_Tech / test_list_perf: 0.09808610317932509
# tested feature: LDA_01 / test_list_perf: 0.09942506155867115
# tested feature: kw_max_avg / test_list_perf: 0.10187768782101381
# tested feature: LDA_03 / test_list_perf: 0.09932474678929837
# tested feature: num_self_hrefs / test_list_perf: 0.09941286541156547
# tested feature: kw_max_min / test_list_perf: 0.09881275967145742
# tested feature: num_videos / test_list_perf: 0.09999461725925951
# tested feature: rate_positive_words / test_list_perf: 0.09995820843536585
# tested feature: num_imgs / test_list_perf: 0.09927348212665743
# tested feature: global_sentiment_polarity / test_list_perf: 0.10026605984398174
# tested feature: kw_min_max / test_list_perf: 0.09924138485455891
# tested feature: self_reference_avg_sharess / test_list_perf: 0.0993607020286219
# tested feature: data_channel_Entertainment / test_list_perf: 0.09929886629490914
# tested feature: max_negative_polarity / test_list_perf: 0.09938824801714274
# tested feature: average_token_length / test_list_perf: 0.09957624025492984
# tested feature: title_subjectivity / test_list_perf: 0.09917807690481506
# tested feature: data_channel_Social Media / test_list_perf: 0.0998240157002992
# tested feature: abs_title_subjectivity / test_list_perf: 0.09929371308721058
# tested feature: kw_avg_min / test_list_perf: 0.09899341615988466
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.09972629497297714
# tested feature: kw_avg_avg / test_list_perf: 0.09902414189220854
# tested feature: avg_negative_polarity / test_list_perf: 0.10005585349180923
# tested feature: rate_negative_words / test_list_perf: 0.09952767625820913
# tested feature: max_positive_polarity / test_list_perf: 0.09938097419769865
# tested feature: n_tokens_title / test_list_perf: 0.10013317523482312
# tested feature: n_tokens_content / test_list_perf: 0.10095198201090994
# tested feature: weekday_Sunday / test_list_perf: 0.10006036437168442
# tested feature: is_weekend / test_list_perf: 0.09903292959291954
# tested feature: global_subjectivity / test_list_perf: 0.0993001857642355
# tested feature: weekday_Thursday / test_list_perf: 0.09930020931655437
# tested feature: weekday_Monday / test_list_perf: 0.09917085047894292
# tested feature: weekday_Tuesday / test_list_perf: 0.09927436164718273
# tested feature: weekday_Wednesday / test_list_perf: 0.09928867378205486
# 성능 개선. best_optional_feature: kw_max_avg // best_optional_perf: 0.10187768782101381
# 고정 개수: 10
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday', 'kw_max_avg']
# fixed_perf: 0.10187768782101381
# tested feature: kw_avg_max / test_list_perf: 0.10229654923804266
# tested feature: global_rate_positive_words / test_list_perf: 0.1027715161954782
# tested feature: kw_min_avg / test_list_perf: 0.10269857984979835
# tested feature: min_positive_polarity / test_list_perf: 0.10169033351286849
# tested feature: LDA_00 / test_list_perf: 0.10153405097199886
# tested feature: min_negative_polarity / test_list_perf: 0.10200280010613405
# tested feature: num_hrefs / test_list_perf: 0.10237827188784887
# tested feature: LDA_02 / test_list_perf: 0.10340263727864463
# tested feature: global_rate_negative_words / test_list_perf: 0.1016119397323828
# tested feature: self_reference_min_shares / test_list_perf: 0.10116682451058134
# tested feature: num_keywords / test_list_perf: 0.10206917813889937
# tested feature: data_channel_Tech / test_list_perf: 0.0999450662396072
# tested feature: LDA_01 / test_list_perf: 0.10169625365240542
# tested feature: LDA_03 / test_list_perf: 0.10166770582001106
# tested feature: num_self_hrefs / test_list_perf: 0.10176484493321336
# tested feature: kw_max_min / test_list_perf: 0.10139182980090289
# tested feature: num_videos / test_list_perf: 0.10235139391897463
# tested feature: rate_positive_words / test_list_perf: 0.10209159399821321
# tested feature: num_imgs / test_list_perf: 0.10171431092605954
# tested feature: global_sentiment_polarity / test_list_perf: 0.10268693105662363
# tested feature: kw_min_max / test_list_perf: 0.10166752056505546
# tested feature: self_reference_avg_sharess / test_list_perf: 0.10179741191242986
# tested feature: data_channel_Entertainment / test_list_perf: 0.10168390312340037
# tested feature: max_negative_polarity / test_list_perf: 0.10173175625783126
# tested feature: average_token_length / test_list_perf: 0.10195771146136068
# tested feature: title_subjectivity / test_list_perf: 0.10159046042590969
# tested feature: data_channel_Social Media / test_list_perf: 0.10227433716088108
# tested feature: abs_title_subjectivity / test_list_perf: 0.10172152071495821
# tested feature: kw_avg_min / test_list_perf: 0.10140946591643407
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10215365512030528
# tested feature: kw_avg_avg / test_list_perf: 0.10142585750464261
# tested feature: avg_negative_polarity / test_list_perf: 0.1023276966210328
# tested feature: rate_negative_words / test_list_perf: 0.10193257116813215
# tested feature: max_positive_polarity / test_list_perf: 0.10178425018548543
# tested feature: n_tokens_title / test_list_perf: 0.10245528127994119
# tested feature: n_tokens_content / test_list_perf: 0.10290604134381365
# tested feature: weekday_Sunday / test_list_perf: 0.1022619126149168
# tested feature: is_weekend / test_list_perf: 0.1014208600994998
# tested feature: global_subjectivity / test_list_perf: 0.10167632758782963
# tested feature: weekday_Thursday / test_list_perf: 0.1016763743925505
# tested feature: weekday_Monday / test_list_perf: 0.10156019741040556
# tested feature: weekday_Tuesday / test_list_perf: 0.10165970685924397
# tested feature: weekday_Wednesday / test_list_perf: 0.10167427425967546
# 성능 개선. best_optional_feature: LDA_02 // best_optional_perf: 0.10340263727864463
# 고정 개수: 11
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday', 'kw_max_avg', 'LDA_02']
# fixed_perf: 0.10340263727864463
# tested feature: kw_avg_max / test_list_perf: 0.10378245637749683
# tested feature: global_rate_positive_words / test_list_perf: 0.10414220590845147
# tested feature: kw_min_avg / test_list_perf: 0.10408347552264663
# tested feature: min_positive_polarity / test_list_perf: 0.10325149223852259
# tested feature: LDA_00 / test_list_perf: 0.10307737163522224
# tested feature: min_negative_polarity / test_list_perf: 0.10352934370377997
# tested feature: num_hrefs / test_list_perf: 0.10382079182073944
# tested feature: global_rate_negative_words / test_list_perf: 0.10314047473605814
# tested feature: self_reference_min_shares / test_list_perf: 0.10272797306693937
# tested feature: num_keywords / test_list_perf: 0.10329610328057248
# tested feature: data_channel_Tech / test_list_perf: 0.10174523204538255
# tested feature: LDA_01 / test_list_perf: 0.10320927227275256
# tested feature: LDA_03 / test_list_perf: 0.1032334373208974
# tested feature: num_self_hrefs / test_list_perf: 0.10330892870968023
# tested feature: kw_max_min / test_list_perf: 0.10327182010632374
# tested feature: num_videos / test_list_perf: 0.10384753792856882
# tested feature: rate_positive_words / test_list_perf: 0.10353238170086487
# tested feature: num_imgs / test_list_perf: 0.10317120059747187
# tested feature: global_sentiment_polarity / test_list_perf: 0.1041438310497963
# tested feature: kw_min_max / test_list_perf: 0.1031549897825409
# tested feature: self_reference_avg_sharess / test_list_perf: 0.10327824938319152
# tested feature: data_channel_Entertainment / test_list_perf: 0.10321243231460864
# tested feature: max_negative_polarity / test_list_perf: 0.10327449546546019
# tested feature: average_token_length / test_list_perf: 0.10335834199785177
# tested feature: title_subjectivity / test_list_perf: 0.10311181675147141
# tested feature: data_channel_Social Media / test_list_perf: 0.10375733538989129
# tested feature: abs_title_subjectivity / test_list_perf: 0.10322712278180823
# tested feature: kw_avg_min / test_list_perf: 0.10292728388730465
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10363857619073347
# tested feature: kw_avg_avg / test_list_perf: 0.10293553327467675
# tested feature: avg_negative_polarity / test_list_perf: 0.10384641845308118
# tested feature: rate_negative_words / test_list_perf: 0.1035211358003646
# tested feature: max_positive_polarity / test_list_perf: 0.10331753469301352
# tested feature: n_tokens_title / test_list_perf: 0.10393432064706443
# tested feature: n_tokens_content / test_list_perf: 0.10408392399651978
# tested feature: weekday_Sunday / test_list_perf: 0.10385982155682283
# tested feature: is_weekend / test_list_perf: 0.10295903525222128
# tested feature: global_subjectivity / test_list_perf: 0.10322697731348729
# tested feature: weekday_Thursday / test_list_perf: 0.10322697698791938
# tested feature: weekday_Monday / test_list_perf: 0.10303191878883478
# tested feature: weekday_Tuesday / test_list_perf: 0.10319661699961702
# tested feature: weekday_Wednesday / test_list_perf: 0.10319802822195956
# 성능 개선. best_optional_feature: global_sentiment_polarity // best_optional_perf: 0.1041438310497963
# 고정 개수: 12
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday', 'kw_max_avg', 'LDA_02', 'global_sentiment_polarity']
# fixed_perf: 0.1041438310497963
# tested feature: kw_avg_max / test_list_perf: 0.1044649602689588
# tested feature: global_rate_positive_words / test_list_perf: 0.10635555750540204
# tested feature: kw_min_avg / test_list_perf: 0.10627591902623801
# tested feature: min_positive_polarity / test_list_perf: 0.10398221875592895
# tested feature: LDA_00 / test_list_perf: 0.1038118667399982
# tested feature: min_negative_polarity / test_list_perf: 0.10419143585463808
# tested feature: num_hrefs / test_list_perf: 0.10614865032656073
# tested feature: global_rate_negative_words / test_list_perf: 0.10388808320969223
# tested feature: self_reference_min_shares / test_list_perf: 0.1034816266974603
# tested feature: num_keywords / test_list_perf: 0.10400917204011695
# tested feature: data_channel_Tech / test_list_perf: 0.10250094090960671
# tested feature: LDA_01 / test_list_perf: 0.1039536652437314
# tested feature: LDA_03 / test_list_perf: 0.10396590414446338
# tested feature: num_self_hrefs / test_list_perf: 0.10402254347757789
# tested feature: kw_max_min / test_list_perf: 0.10406772698943889
# tested feature: num_videos / test_list_perf: 0.1046391390371082
# tested feature: rate_positive_words / test_list_perf: 0.10417756055210359
# tested feature: num_imgs / test_list_perf: 0.10390696050790893
# tested feature: kw_min_max / test_list_perf: 0.10387055384119548
# tested feature: self_reference_avg_sharess / test_list_perf: 0.10389066325691909
# tested feature: data_channel_Entertainment / test_list_perf: 0.10395263803045962
# tested feature: max_negative_polarity / test_list_perf: 0.10449756196215876
# tested feature: average_token_length / test_list_perf: 0.10427954424058772
# tested feature: title_subjectivity / test_list_perf: 0.10374087857458314
# tested feature: data_channel_Social Media / test_list_perf: 0.10489223463140485
# tested feature: abs_title_subjectivity / test_list_perf: 0.10394381488157445
# tested feature: kw_avg_min / test_list_perf: 0.10348018603307241
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10409918646734928
# tested feature: kw_avg_avg / test_list_perf: 0.10387054678658147
# tested feature: avg_negative_polarity / test_list_perf: 0.10439885149616102
# tested feature: rate_negative_words / test_list_perf: 0.10421221447727502
# tested feature: max_positive_polarity / test_list_perf: 0.10405966620343843
# tested feature: n_tokens_title / test_list_perf: 0.10453967645399731
# tested feature: n_tokens_content / test_list_perf: 0.10463478944370008
# tested feature: weekday_Sunday / test_list_perf: 0.10454206053331727
# tested feature: is_weekend / test_list_perf: 0.10367859364682086
# tested feature: global_subjectivity / test_list_perf: 0.1039567384600043
# tested feature: weekday_Thursday / test_list_perf: 0.10395676075899918
# tested feature: weekday_Monday / test_list_perf: 0.10376029625802918
# tested feature: weekday_Tuesday / test_list_perf: 0.10393878339558549
# tested feature: weekday_Wednesday / test_list_perf: 0.10394054596058055
# 성능 개선. best_optional_feature: global_rate_positive_words // best_optional_perf: 0.10635555750540204
# 고정 개수: 13
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday', 'kw_max_avg', 'LDA_02', 'global_sentiment_polarity', 'global_rate_positive_words']
# fixed_perf: 0.10635555750540204
# tested feature: kw_avg_max / test_list_perf: 0.10612983512082919
# tested feature: kw_min_avg / test_list_perf: 0.10626550308007876
# tested feature: min_positive_polarity / test_list_perf: 0.10623037142527969
# tested feature: LDA_00 / test_list_perf: 0.10583175088421226
# tested feature: min_negative_polarity / test_list_perf: 0.10642706390192036
# tested feature: num_hrefs / test_list_perf: 0.10678059197469425
# tested feature: global_rate_negative_words / test_list_perf: 0.10610763527799849
# tested feature: self_reference_min_shares / test_list_perf: 0.10571606414342472
# tested feature: num_keywords / test_list_perf: 0.10625347768850246
# tested feature: data_channel_Tech / test_list_perf: 0.10470606606951138
# tested feature: LDA_01 / test_list_perf: 0.10615485124361146
# tested feature: LDA_03 / test_list_perf: 0.10619471217124254
# tested feature: num_self_hrefs / test_list_perf: 0.1062551973198469
# tested feature: kw_max_min / test_list_perf: 0.1063041847739592
# tested feature: num_videos / test_list_perf: 0.10676266190295947
# tested feature: rate_positive_words / test_list_perf: 0.10646209691969921
# tested feature: num_imgs / test_list_perf: 0.1061141692167773
# tested feature: kw_min_max / test_list_perf: 0.10607933850060214
# tested feature: self_reference_avg_sharess / test_list_perf: 0.10611607051116334
# tested feature: data_channel_Entertainment / test_list_perf: 0.1061534501813004
# tested feature: max_negative_polarity / test_list_perf: 0.10622336513416675
# tested feature: average_token_length / test_list_perf: 0.1062082796199153
# tested feature: title_subjectivity / test_list_perf: 0.10588608081014561
# tested feature: data_channel_Social Media / test_list_perf: 0.10641859713046686
# tested feature: abs_title_subjectivity / test_list_perf: 0.10616334079225587
# tested feature: kw_avg_min / test_list_perf: 0.10570777598275094
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10618228200003221
# tested feature: kw_avg_avg / test_list_perf: 0.10579174690438808
# tested feature: avg_negative_polarity / test_list_perf: 0.1065306589374122
# tested feature: rate_negative_words / test_list_perf: 0.10634343384355405
# tested feature: max_positive_polarity / test_list_perf: 0.10624200679407125
# tested feature: n_tokens_title / test_list_perf: 0.10660920326503853
# tested feature: n_tokens_content / test_list_perf: 0.1070021569403542
# tested feature: weekday_Sunday / test_list_perf: 0.10681931276614187
# tested feature: is_weekend / test_list_perf: 0.1058814553639641
# tested feature: global_subjectivity / test_list_perf: 0.10616028050581294
# tested feature: weekday_Thursday / test_list_perf: 0.10616030862565473
# tested feature: weekday_Monday / test_list_perf: 0.10597375965157596
# tested feature: weekday_Tuesday / test_list_perf: 0.10614979421637627
# tested feature: weekday_Wednesday / test_list_perf: 0.10615344939388371
# 성능 개선. best_optional_feature: n_tokens_content // best_optional_perf: 0.1070021569403542
# 고정 개수: 14
# fixed_list: ['data_channel_Lifestyle', 'self_reference_max_shares', 'n_unique_tokens', 'abs_title_sentiment_polarity', 'avg_positive_polarity', 'title_sentiment_polarity', 'data_channel_World', 'LDA_04', 'weekday_Saturday', 'kw_max_avg', 'LDA_02', 'global_sentiment_polarity', 'global_rate_positive_words', 'n_tokens_content']
# fixed_perf: 0.1070021569403542
# tested feature: kw_avg_max / test_list_perf: 0.10684062171931885
# tested feature: kw_min_avg / test_list_perf: 0.10689180790685959
# tested feature: min_positive_polarity / test_list_perf: 0.10684396560731113
# tested feature: LDA_00 / test_list_perf: 0.10646884170326909
# tested feature: min_negative_polarity / test_list_perf: 0.10692587955706911
# tested feature: num_hrefs / test_list_perf: 0.10718319217382721
# tested feature: global_rate_negative_words / test_list_perf: 0.10675885014826847
# tested feature: self_reference_min_shares / test_list_perf: 0.10643736776138923
# tested feature: num_keywords / test_list_perf: 0.1068562949174019
# tested feature: data_channel_Tech / test_list_perf: 0.10533753888474384
# tested feature: LDA_01 / test_list_perf: 0.10681114538778813
# tested feature: LDA_03 / test_list_perf: 0.10677584682982733
# tested feature: num_self_hrefs / test_list_perf: 0.10688466537408392
# tested feature: kw_max_min / test_list_perf: 0.10828161925834989
# ...
# tested feature: rate_negative_words / test_list_perf: 0.09478060965261459
# tested feature: max_positive_polarity / test_list_perf: 0.09450020813658566
# tested feature: n_tokens_title / test_list_perf: 0.09473930152444165
# tested feature: avg_positive_polarity / test_list_perf: 0.0957435762861154
# tested feature: n_tokens_content / test_list_perf: 0.09481484394435846
# tested feature: title_sentiment_polarity / test_list_perf: 0.10016926606766774
# tested feature: weekday_Saturday / test_list_perf: 0.09636289572176071
# tested feature: weekday_Sunday / test_list_perf: 0.09545702367106534
# tested feature: is_weekend / test_list_perf: 0.09414620435608068
# tested feature: global_subjectivity / test_list_perf: 0.09445178585807712
# tested feature: weekday_Thursday / test_list_perf: 0.09445182394665652
# tested feature: weekday_Monday / test_list_perf: 0.09430935859998346
# tested feature: weekday_Tuesday / test_list_perf: 0.09429000621548989
# tested feature: weekday_Wednesday / test_list_perf: 0.09443283823679927
# 성능 개선. best_optional_feature: title_sentiment_polarity // best_optional_perf: 0.10016926606766774
# 고정 개수: 33
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity']
# fixed_perf: 0.10016926606766774
# tested feature: title_subjectivity / test_list_perf: 0.09974748635165254
# tested feature: data_channel_Social Media / test_list_perf: 0.10008212455287291
# tested feature: abs_title_subjectivity / test_list_perf: 0.09995363740821994
# tested feature: kw_avg_min / test_list_perf: 0.09970476685884022
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10000679826519032
# tested feature: kw_avg_avg / test_list_perf: 0.09969435744750088
# tested feature: avg_negative_polarity / test_list_perf: 0.10026387737414388
# tested feature: rate_negative_words / test_list_perf: 0.10019297955044693
# tested feature: max_positive_polarity / test_list_perf: 0.10004529901897596
# tested feature: n_tokens_title / test_list_perf: 0.10028067556101672
# tested feature: avg_positive_polarity / test_list_perf: 0.10080162968103723
# tested feature: n_tokens_content / test_list_perf: 0.10087084489963816
# tested feature: weekday_Saturday / test_list_perf: 0.10255335064091187
# tested feature: weekday_Sunday / test_list_perf: 0.10032971920117417
# tested feature: is_weekend / test_list_perf: 0.09968864683674317
# tested feature: global_subjectivity / test_list_perf: 0.0999688162169825
# tested feature: weekday_Thursday / test_list_perf: 0.09996886998238808
# tested feature: weekday_Monday / test_list_perf: 0.09982685375501055
# tested feature: weekday_Tuesday / test_list_perf: 0.09989797118719346
# tested feature: weekday_Wednesday / test_list_perf: 0.09996539038893659
# 성능 개선. best_optional_feature: weekday_Saturday // best_optional_perf: 0.10255335064091187
# 고정 개수: 34
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday']
# fixed_perf: 0.10255335064091187
# tested feature: title_subjectivity / test_list_perf: 0.10214841940033548
# tested feature: data_channel_Social Media / test_list_perf: 0.10249907456608331
# tested feature: abs_title_subjectivity / test_list_perf: 0.10232434234796028
# tested feature: kw_avg_min / test_list_perf: 0.10211380109882806
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10243490409308653
# tested feature: kw_avg_avg / test_list_perf: 0.10207596349363868
# tested feature: avg_negative_polarity / test_list_perf: 0.10267379664758369
# tested feature: rate_negative_words / test_list_perf: 0.10256024796221341
# tested feature: max_positive_polarity / test_list_perf: 0.10244161708770572
# tested feature: n_tokens_title / test_list_perf: 0.10270033647468957
# tested feature: avg_positive_polarity / test_list_perf: 0.10286056272897781
# tested feature: n_tokens_content / test_list_perf: 0.10452421009158797
# tested feature: weekday_Sunday / test_list_perf: 0.10230017173193173
# tested feature: is_weekend / test_list_perf: 0.10207213213855659
# tested feature: global_subjectivity / test_list_perf: 0.10233933744223644
# tested feature: weekday_Thursday / test_list_perf: 0.1023394100125925
# tested feature: weekday_Monday / test_list_perf: 0.10221620257681885
# tested feature: weekday_Tuesday / test_list_perf: 0.10228504147842465
# tested feature: weekday_Wednesday / test_list_perf: 0.10235239604780055
# 성능 개선. best_optional_feature: n_tokens_content // best_optional_perf: 0.10452421009158797
# 고정 개수: 35
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content']
# fixed_perf: 0.10452421009158797
# tested feature: title_subjectivity / test_list_perf: 0.10405779613599553
# tested feature: data_channel_Social Media / test_list_perf: 0.10452017428642368
# tested feature: abs_title_subjectivity / test_list_perf: 0.10427885364082934
# tested feature: kw_avg_min / test_list_perf: 0.10407331950475152
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10441985737437631
# tested feature: kw_avg_avg / test_list_perf: 0.1040409437556129
# tested feature: avg_negative_polarity / test_list_perf: 0.1046408370199452
# tested feature: rate_negative_words / test_list_perf: 0.10444208751667328
# tested feature: max_positive_polarity / test_list_perf: 0.10437743534085597
# tested feature: n_tokens_title / test_list_perf: 0.10464516399847346
# tested feature: avg_positive_polarity / test_list_perf: 0.1039738194563079
# tested feature: weekday_Sunday / test_list_perf: 0.10457751618669853
# tested feature: is_weekend / test_list_perf: 0.10402168989312899
# tested feature: global_subjectivity / test_list_perf: 0.10430334962388699
# tested feature: weekday_Thursday / test_list_perf: 0.10430342872526277
# tested feature: weekday_Monday / test_list_perf: 0.10420712480679184
# tested feature: weekday_Tuesday / test_list_perf: 0.10423754128182228
# tested feature: weekday_Wednesday / test_list_perf: 0.1043241446951898
# 성능 개선. best_optional_feature: n_tokens_title // best_optional_perf: 0.10464516399847346
# 고정 개수: 36
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title']
# fixed_perf: 0.10464516399847346
# tested feature: title_subjectivity / test_list_perf: 0.10418108032948359
# tested feature: data_channel_Social Media / test_list_perf: 0.10465617281773876
# tested feature: abs_title_subjectivity / test_list_perf: 0.10440257684746634
# tested feature: kw_avg_min / test_list_perf: 0.10416567817600786
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10452515937745432
# tested feature: kw_avg_avg / test_list_perf: 0.10415524158314293
# tested feature: avg_negative_polarity / test_list_perf: 0.10424138102422997
# tested feature: rate_negative_words / test_list_perf: 0.10422677797781588
# tested feature: max_positive_polarity / test_list_perf: 0.10477958236099227
# tested feature: avg_positive_polarity / test_list_perf: 0.10408797166629857
# tested feature: weekday_Sunday / test_list_perf: 0.10468361166288997
# tested feature: is_weekend / test_list_perf: 0.10414000948437374
# tested feature: global_subjectivity / test_list_perf: 0.10442729117120642
# tested feature: weekday_Thursday / test_list_perf: 0.10442736646373685
# tested feature: weekday_Monday / test_list_perf: 0.1043299432960344
# tested feature: weekday_Tuesday / test_list_perf: 0.10435958471386964
# tested feature: weekday_Wednesday / test_list_perf: 0.1044443312341704
# 성능 개선. best_optional_feature: max_positive_polarity // best_optional_perf: 0.10477958236099227
# 고정 개수: 37
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity']
# fixed_perf: 0.10477958236099227
# tested feature: title_subjectivity / test_list_perf: 0.10431604269480388
# tested feature: data_channel_Social Media / test_list_perf: 0.10478384419154185
# tested feature: abs_title_subjectivity / test_list_perf: 0.10453907122229433
# tested feature: kw_avg_min / test_list_perf: 0.10430321322634128
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.1046427987144446
# tested feature: kw_avg_avg / test_list_perf: 0.10428391086291411
# tested feature: avg_negative_polarity / test_list_perf: 0.10444419453233234
# tested feature: rate_negative_words / test_list_perf: 0.10440337080570194
# tested feature: avg_positive_polarity / test_list_perf: 0.10424425455992958
# tested feature: weekday_Sunday / test_list_perf: 0.10481977094985406
# tested feature: is_weekend / test_list_perf: 0.10427309932087736
# tested feature: global_subjectivity / test_list_perf: 0.10455771126465685
# tested feature: weekday_Thursday / test_list_perf: 0.10455779394235587
# tested feature: weekday_Monday / test_list_perf: 0.10446996803864128
# tested feature: weekday_Tuesday / test_list_perf: 0.10450809889981238
# tested feature: weekday_Wednesday / test_list_perf: 0.10457875653067372
# 성능 개선. best_optional_feature: weekday_Sunday // best_optional_perf: 0.10481977094985406
# 고정 개수: 38
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity', 'weekday_Sunday']
# fixed_perf: 0.10481977094985406
# tested feature: title_subjectivity / test_list_perf: 0.10436454277720553
# tested feature: data_channel_Social Media / test_list_perf: 0.10482444877176966
# tested feature: abs_title_subjectivity / test_list_perf: 0.10457547547964507
# tested feature: kw_avg_min / test_list_perf: 0.10435111627624849
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.10469852502848875
# tested feature: kw_avg_avg / test_list_perf: 0.10432282835077189
# tested feature: avg_negative_polarity / test_list_perf: 0.10448487895717096
# tested feature: rate_negative_words / test_list_perf: 0.1044233756024745
# tested feature: avg_positive_polarity / test_list_perf: 0.10420742408740202
# tested feature: is_weekend / test_list_perf: 0.10432696601660463
# tested feature: global_subjectivity / test_list_perf: 0.10460687545923475
# tested feature: weekday_Thursday / test_list_perf: 0.10460694021183448
# tested feature: weekday_Monday / test_list_perf: 0.10451104012934331
# tested feature: weekday_Tuesday / test_list_perf: 0.10456706121934911
# tested feature: weekday_Wednesday / test_list_perf: 0.10461677069890629
# 성능 개선. best_optional_feature: data_channel_Social Media // best_optional_perf: 0.10482444877176966
# 고정 개수: 39
# fixed_list: ['data_channel_Lifestyle', 'kw_avg_max', 'global_rate_positive_words', 'kw_min_avg', 'data_channel_World', 'min_positive_polarity', 'LDA_00', 'min_negative_polarity', 'num_hrefs', 'LDA_02', 'global_rate_negative_words', 'self_reference_min_shares', 'num_keywords', 'data_channel_Tech', 'LDA_01', 'kw_max_avg', 'self_reference_max_shares', 'LDA_04', 'LDA_03', 'num_self_hrefs', 'kw_max_min', 'num_videos', 'abs_title_sentiment_polarity', 'rate_positive_words', 'num_imgs', 'global_sentiment_polarity', 'kw_min_max', 'self_reference_avg_sharess', 'data_channel_Entertainment', 'max_negative_polarity', 'average_token_length', 'n_unique_tokens', 'title_sentiment_polarity', 'weekday_Saturday', 'n_tokens_content', 'n_tokens_title', 'max_positive_polarity', 'weekday_Sunday', 'data_channel_Social Media']
# fixed_perf: 0.10482444877176966
# tested feature: title_subjectivity / test_list_perf: 0.10451101419458475
# tested feature: abs_title_subjectivity / test_list_perf: 0.10458441804702445
# tested feature: kw_avg_min / test_list_perf: 0.10432840120451248
# tested feature: n_non_stop_unique_tokens / test_list_perf: 0.1046856825100565
# tested feature: kw_avg_avg / test_list_perf: 0.10429936280717056
# tested feature: avg_negative_polarity / test_list_perf: 0.10450243025049555
# tested feature: rate_negative_words / test_list_perf: 0.10444099767269521
# tested feature: avg_positive_polarity / test_list_perf: 0.10420423396093725
# tested feature: is_weekend / test_list_perf: 0.1043271902183085
# tested feature: global_subjectivity / test_list_perf: 0.10461297752425713
# tested feature: weekday_Thursday / test_list_perf: 0.10461303772985064
# tested feature: weekday_Monday / test_list_perf: 0.10451268804801006
# tested feature: weekday_Tuesday / test_list_perf: 0.1045649632463106
# tested feature: weekday_Wednesday / test_list_perf: 0.10462232748412914
# 성능 개선 불가하므로 멈춤.
# number of features: 39
# fixed_perf: 0.10482444877176966 / best_optional_perf: 0.1046856825100565
# N: 31 / got[1]: 0.10482444877176966
#
# best_perf_subset = 1
# best_perf[1] = 0.10917480240207988

# %%
# 각 N에 대한 forward selection 결과를 판다스 데이터프레임으로 만들어서 출력
perf_list = [(k, v[1]) for k, v in results_dict.items()]
df_perf = pd.DataFrame(perf_list, columns=['N', 'performance'])
print(df_perf)
# Out:
#     N  performance
# 0   1     0.109175
# 1   6     0.108825
# 2  13     0.107489
# 3  21     0.106019
# 4  31     0.104824

# %%
# 가장 좋은 성능의 subset(list) 출력
results_dict[best_perf_subset][0]
# Out:
# ['data_channel_Lifestyle',
#  'self_reference_max_shares',
#  'n_unique_tokens',
#  'abs_title_sentiment_polarity',
#  'avg_positive_polarity',
#  'title_sentiment_polarity',
#  'data_channel_World',
#  'LDA_04',
#  'weekday_Saturday',
#  'kw_max_avg',
#  'LDA_02',
#  'global_sentiment_polarity',
#  'global_rate_positive_words',
#  'n_tokens_content',
#  'kw_max_min',
#  'num_hrefs',
#  'num_videos',
#  'n_tokens_title',
#  'max_positive_polarity',
#  'data_channel_Social Media',
#  'weekday_Sunday']
